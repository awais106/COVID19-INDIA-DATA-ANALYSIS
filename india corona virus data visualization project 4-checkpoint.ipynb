# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
#import time#for enhancin the image of graph
#import psutil

# %%
#%matplotlib notebook
#plt.rcParams['animation.html'] = 'jshtml'#java script & html structure

# %%
data = pd.read_csv(r"C:\Users\BBi5D3\project 4 india corona virus data\covid_19_india.csv")

# %%
data.describe()
# Out:
#                Sno         Cured        Deaths     Confirmed
# count  7086.000000  7.086000e+03   7086.000000  7.086000e+03
# mean   3543.500000  3.423502e+04    836.188682  4.534495e+04
# std    2045.696336  9.913313e+04   2997.188810  1.263801e+05
# min       1.000000  0.000000e+00      0.000000  0.000000e+00
# 25%    1772.250000  3.800000e+01      1.000000  1.660000e+02
# 50%    3543.500000  1.499500e+03     22.000000  2.774000e+03
# 75%    5314.750000  1.664325e+04    396.000000  2.573375e+04
# max    7086.000000  1.179726e+06  38717.000000  1.465911e+06

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7086 entries, 0 to 7085
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Sno                       7086 non-null   int64
#  1   Date                      7086 non-null   object
#  2   Time                      7086 non-null   object
#  3   State/UnionTerritory      7086 non-null   object
#  4   ConfirmedIndianNational   7086 non-null   object
#  5   ConfirmedForeignNational  7086 non-null   object
#  6   Cured                     7086 non-null   int64
#  7   Deaths                    7086 non-null   int64
#  8   Confirmed                 7086 non-null   int64
# dtypes: int64(4), object(5)
# memory usage: 498.4+ KB

# %%
data.tail()
# Out:
#        Sno      Date StatesUniounTerritories   Cured  Deaths  Confirmed  Month
# 7081  7082  07/10/20               Telangana  177008    1189     204748     10
# 7082  7083  07/10/20                 Tripura   22623     301      27545     10
# 7083  7084  07/10/20             Uttarakhand   43238     677      52329     10
# 7084  7085  07/10/20            UttarPradesh  370753    6153     420937     10
# 7085  7086  07/10/20              WestBengal  243743    5318     277049     10

# %%
data.columns
# Out:
# Index(['Sno', 'Date', 'Time', 'State/UnionTerritory',
#        'ConfirmedIndianNational', 'ConfirmedForeignNational', 'Cured',
#        'Deaths', 'Confirmed'],
#       dtype='object')

# %%
no_use_rows = data.loc[pd.to_numeric(data['ConfirmedIndianNational'], errors='coerce').isnull()]#finding strings in columns
no_use_rows
# Out:
#        Sno      Date     Time         State/UnionTerritory  \
# 446    447  29/03/20  7:30 PM               Andhra Pradesh
# 447    448  29/03/20  7:30 PM  Andaman and Nicobar Islands
# 448    449  29/03/20  7:30 PM                        Bihar
# 449    450  29/03/20  7:30 PM                   Chandigarh
# 450    451  29/03/20  7:30 PM                 Chhattisgarh
# ...    ...       ...      ...                          ...
# 7081  7082  07/10/20  8:00 AM                    Telengana
# 7082  7083  07/10/20  8:00 AM                      Tripura
# 7083  7084  07/10/20  8:00 AM                  Uttarakhand
# 7084  7085  07/10/20  8:00 AM                Uttar Pradesh
# 7085  7086  07/10/20  8:00 AM                  West Bengal
#
#      ConfirmedIndianNational ConfirmedForeignNational   Cured  Deaths  \
# 446                        -                        -       1       0
# 447                        -                        -       0       0
# 448                        -                        -       0       1
# 449                        -                        -       0       0
# 450                        -                        -       0       0
# ...                      ...                      ...     ...     ...
# 7081                       -                        -  177008    1189
# 7082                       -                        -   22623     301
# 7083                       -                        -   43238     677
# 7084                       -                        -  370753    6153
# 7085                       -                        -  243743    5318
#
#       Confirmed
# 446          19
# 447           9
# 448          11
# 449           8
# 450           7
# ...         ...
# 7081     204748
# 7082      27545
# 7083      52329
# 7084     420937
# 7085     277049
#
# [6640 rows x 9 columns]

# %%
del data['ConfirmedIndianNational']#deleting column 
data.head()
# Out:
#    Sno      Date     Time State/UnionTerritory ConfirmedForeignNational  \
# 0    1  30/01/20  6:00 PM               Kerala                        0
# 1    2  31/01/20  6:00 PM               Kerala                        0
# 2    3  01/02/20  6:00 PM               Kerala                        0
# 3    4  02/02/20  6:00 PM               Kerala                        0
# 4    5  03/02/20  6:00 PM               Kerala                        0
#
#    Cured  Deaths  Confirmed
# 0      0       0          1
# 1      0       0          1
# 2      0       0          2
# 3      0       0          3
# 4      0       0          3

# %%
del data['ConfirmedForeignNational']#deleting column

# %%
data.head(2119)
# Out:
#        Sno      Date     Time State/UnionTerritory  Cured  Deaths  Confirmed
# 0        1  30/01/20  6:00 PM               Kerala      0       0          1
# 1        2  31/01/20  6:00 PM               Kerala      0       0          1
# 2        3  01/02/20  6:00 PM               Kerala      0       0          2
# 3        4  02/02/20  6:00 PM               Kerala      0       0          3
# 4        5  03/02/20  6:00 PM               Kerala      0       0          3
# ...    ...       ...      ...                  ...    ...     ...        ...
# 2114  2115  20/05/20  8:00 AM            Jharkhand    127       3        231
# 2115  2116  20/05/20  8:00 AM            Karnataka    544      40       1397
# 2116  2117  20/05/20  8:00 AM               Kerala    497       4        642
# 2117  2118  20/05/20  8:00 AM               Ladakh     43       0         43
# 2118  2119  20/05/20  8:00 AM       Madhya Pradesh   2630     258       5465
#
# [2119 rows x 7 columns]

# %%
data.tail(50)
# Out:
#        Sno      Date     Time                      State/UnionTerritory  \
# 7036  7037  06/10/20  8:00 AM                                   Manipur
# 7037  7038  06/10/20  8:00 AM                                 Meghalaya
# 7038  7039  06/10/20  8:00 AM                                   Mizoram
# 7039  7040  06/10/20  8:00 AM                                  Nagaland
# 7040  7041  06/10/20  8:00 AM                                    Odisha
# 7041  7042  06/10/20  8:00 AM                                Puducherry
# 7042  7043  06/10/20  8:00 AM                                    Punjab
# 7043  7044  06/10/20  8:00 AM                                 Rajasthan
# 7044  7045  06/10/20  8:00 AM                                    Sikkim
# 7045  7046  06/10/20  8:00 AM                                Tamil Nadu
# 7046  7047  06/10/20  8:00 AM                                 Telengana
# 7047  7048  06/10/20  8:00 AM                                   Tripura
# 7048  7049  06/10/20  8:00 AM                               Uttarakhand
# 7049  7050  06/10/20  8:00 AM                             Uttar Pradesh
# 7050  7051  06/10/20  8:00 AM                               West Bengal
# 7051  7052  07/10/20  8:00 AM               Andaman and Nicobar Islands
# 7052  7053  07/10/20  8:00 AM                            Andhra Pradesh
# 7053  7054  07/10/20  8:00 AM                         Arunachal Pradesh
# 7054  7055  07/10/20  8:00 AM                                     Assam
# 7055  7056  07/10/20  8:00 AM                                     Bihar
# 7056  7057  07/10/20  8:00 AM                                Chandigarh
# 7057  7058  07/10/20  8:00 AM                              Chhattisgarh
# 7058  7059  07/10/20  8:00 AM  Dadra and Nagar Haveli and Daman and Diu
# 7059  7060  07/10/20  8:00 AM                                     Delhi
# 7060  7061  07/10/20  8:00 AM                                       Goa
# 7061  7062  07/10/20  8:00 AM                                   Gujarat
# 7062  7063  07/10/20  8:00 AM                                   Haryana
# 7063  7064  07/10/20  8:00 AM                          Himachal Pradesh
# 7064  7065  07/10/20  8:00 AM                         Jammu and Kashmir
# 7065  7066  07/10/20  8:00 AM                                 Jharkhand
# 7066  7067  07/10/20  8:00 AM                                 Karnataka
# 7067  7068  07/10/20  8:00 AM                                    Kerala
# 7068  7069  07/10/20  8:00 AM                                    Ladakh
# 7069  7070  07/10/20  8:00 AM                            Madhya Pradesh
# 7070  7071  07/10/20  8:00 AM                               Maharashtra
# 7071  7072  07/10/20  8:00 AM                                   Manipur
# 7072  7073  07/10/20  8:00 AM                                 Meghalaya
# 7073  7074  07/10/20  8:00 AM                                   Mizoram
# 7074  7075  07/10/20  8:00 AM                                  Nagaland
# 7075  7076  07/10/20  8:00 AM                                    Odisha
# 7076  7077  07/10/20  8:00 AM                                Puducherry
# 7077  7078  07/10/20  8:00 AM                                    Punjab
# 7078  7079  07/10/20  8:00 AM                                 Rajasthan
# 7079  7080  07/10/20  8:00 AM                                    Sikkim
# 7080  7081  07/10/20  8:00 AM                                Tamil Nadu
# 7081  7082  07/10/20  8:00 AM                                 Telengana
# 7082  7083  07/10/20  8:00 AM                                   Tripura
# 7083  7084  07/10/20  8:00 AM                               Uttarakhand
# 7084  7085  07/10/20  8:00 AM                             Uttar Pradesh
# 7085  7086  07/10/20  8:00 AM                               West Bengal
#
#         Cured  Deaths  Confirmed
# 7036     9334      75      12105
# 7037     4491      59       6767
# 7038     1837       0       2128
# 7039     5422      17       6594
# 7040   206400     924     235330
# 7041    24221     543      29277
# 7042   102648    3641     119184
# 7043   123421    1559     146195
# 7044     2547      46       3191
# 7045   569664    9846     625391
# 7046   174769    1181     202594
# 7047    22131     301      27308
# 7048    42621     669      51991
# 7049   366321    6092     417437
# 7050   240707    5255     273679
# 7051     3678      54       3912
# 7052   672479    6052     729307
# 7053     7965      20      11007
# 7054   155077     778     188902
# 7055   178395     925     190740
# 7056    11035     180      12707
# 7057   100551    1104     128893
# 7058     3000       2       3103
# 7059   266935    5581     295236
# 7060    31050     468      36238
# 7061   125111    3519     145200
# 7062   123286    1509     136115
# 7063    12918     229      16283
# 7064    65496    1268      80476
# 7065    78089     757      88873
# 7066   533074    9461     657705
# 7067   154092     884     242799
# 7068     3464      61       4720
# 7069   118039    2488     138668
# 7070  1179726   38717    1465911
# 7071     9482      78      12240
# 7072     4606      60       7037
# 7073     1887       0       2148
# 7074     5460      17       6662
# 7075   210217     940     238003
# 7076    24614     546      29682
# 7077   104355    3679     120016
# 7078   125448    1574     148316
# 7079     2587      49       3216
# 7080   575212    9917     630408
# 7081   177008    1189     204748
# 7082    22623     301      27545
# 7083    43238     677      52329
# 7084   370753    6153     420937
# 7085   243743    5318     277049

# %% [markdown]
# ##### renaming the state/unionTerritory column

# %%
data.rename(columns = {'State/UnionTerritory':'StatesUniounTerritories'}, inplace = True)
data
# Out:
#        Sno      Date     Time StatesUniounTerritories   Cured  Deaths  \
# 0        1  30/01/20  6:00 PM                  Kerala       0       0
# 1        2  31/01/20  6:00 PM                  Kerala       0       0
# 2        3  01/02/20  6:00 PM                  Kerala       0       0
# 3        4  02/02/20  6:00 PM                  Kerala       0       0
# 4        5  03/02/20  6:00 PM                  Kerala       0       0
# ...    ...       ...      ...                     ...     ...     ...
# 7081  7082  07/10/20  8:00 AM               Telengana  177008    1189
# 7082  7083  07/10/20  8:00 AM                 Tripura   22623     301
# 7083  7084  07/10/20  8:00 AM             Uttarakhand   43238     677
# 7084  7085  07/10/20  8:00 AM           Uttar Pradesh  370753    6153
# 7085  7086  07/10/20  8:00 AM             West Bengal  243743    5318
#
#       Confirmed
# 0             1
# 1             1
# 2             2
# 3             3
# 4             3
# ...         ...
# 7081     204748
# 7082      27545
# 7083      52329
# 7084     420937
# 7085     277049
#
# [7086 rows x 7 columns]

# %%
data["StatesUniounTerritories"]= data["StatesUniounTerritories"].str.replace(r'\W',"")#removing all the special characters
#using (r'\W',"") also it replaces the string with other name if we want
data
# Out:
#        Sno      Date     Time StatesUniounTerritories   Cured  Deaths  \
# 0        1  30/01/20  6:00 PM                  Kerala       0       0
# 1        2  31/01/20  6:00 PM                  Kerala       0       0
# 2        3  01/02/20  6:00 PM                  Kerala       0       0
# 3        4  02/02/20  6:00 PM                  Kerala       0       0
# 4        5  03/02/20  6:00 PM                  Kerala       0       0
# ...    ...       ...      ...                     ...     ...     ...
# 7081  7082  07/10/20  8:00 AM               Telengana  177008    1189
# 7082  7083  07/10/20  8:00 AM                 Tripura   22623     301
# 7083  7084  07/10/20  8:00 AM             Uttarakhand   43238     677
# 7084  7085  07/10/20  8:00 AM            UttarPradesh  370753    6153
# 7085  7086  07/10/20  8:00 AM              WestBengal  243743    5318
#
#       Confirmed
# 0             1
# 1             1
# 2             2
# 3             3
# 4             3
# ...         ...
# 7081     204748
# 7082      27545
# 7083      52329
# 7084     420937
# 7085     277049
#
# [7086 rows x 7 columns]

# %%
data["StatesUniounTerritories"]= data["StatesUniounTerritories"].str.replace('Telengana', "Telangana")#replacing string
#telengana to telangana
data
# Out:
#        Sno      Date     Time StatesUniounTerritories   Cured  Deaths  \
# 0        1  30/01/20  6:00 PM                  Kerala       0       0
# 1        2  31/01/20  6:00 PM                  Kerala       0       0
# 2        3  01/02/20  6:00 PM                  Kerala       0       0
# 3        4  02/02/20  6:00 PM                  Kerala       0       0
# 4        5  03/02/20  6:00 PM                  Kerala       0       0
# ...    ...       ...      ...                     ...     ...     ...
# 7081  7082  07/10/20  8:00 AM               Telangana  177008    1189
# 7082  7083  07/10/20  8:00 AM                 Tripura   22623     301
# 7083  7084  07/10/20  8:00 AM             Uttarakhand   43238     677
# 7084  7085  07/10/20  8:00 AM            UttarPradesh  370753    6153
# 7085  7086  07/10/20  8:00 AM              WestBengal  243743    5318
#
#       Confirmed
# 0             1
# 1             1
# 2             2
# 3             3
# 4             3
# ...         ...
# 7081     204748
# 7082      27545
# 7083      52329
# 7084     420937
# 7085     277049
#
# [7086 rows x 7 columns]

# %% [markdown]
# ## Merging two columns with slightly different name that will cause an error

# %%
data["StatesUniounTerritories"]= data["StatesUniounTerritories"].str.replace('DadarNagarHaveli', "DadraandNagarHaveliandDamanandDiu")#replacing string
#DadarNagarHaveli to DadraandNagarHaveliandDamanandDiu
data
# Out:
#        Sno      Date     Time StatesUniounTerritories   Cured  Deaths  \
# 0        1  30/01/20  6:00 PM                  Kerala       0       0
# 1        2  31/01/20  6:00 PM                  Kerala       0       0
# 2        3  01/02/20  6:00 PM                  Kerala       0       0
# 3        4  02/02/20  6:00 PM                  Kerala       0       0
# 4        5  03/02/20  6:00 PM                  Kerala       0       0
# ...    ...       ...      ...                     ...     ...     ...
# 7081  7082  07/10/20  8:00 AM               Telangana  177008    1189
# 7082  7083  07/10/20  8:00 AM                 Tripura   22623     301
# 7083  7084  07/10/20  8:00 AM             Uttarakhand   43238     677
# 7084  7085  07/10/20  8:00 AM            UttarPradesh  370753    6153
# 7085  7086  07/10/20  8:00 AM              WestBengal  243743    5318
#
#       Confirmed
# 0             1
# 1             1
# 2             2
# 3             3
# 4             3
# ...         ...
# 7081     204748
# 7082      27545
# 7083      52329
# 7084     420937
# 7085     277049
#
# [7086 rows x 7 columns]

# %%
data["StatesUniounTerritories"]= data["StatesUniounTerritories"].str.replace('DamanDiu', "DadraandNagarHaveliandDamanandDiu")#replacing string
#DamanDiu to DadraandNagarHaveliandDamanandDiu
data
# Out:
#        Sno      Date     Time StatesUniounTerritories   Cured  Deaths  \
# 0        1  30/01/20  6:00 PM                  Kerala       0       0
# 1        2  31/01/20  6:00 PM                  Kerala       0       0
# 2        3  01/02/20  6:00 PM                  Kerala       0       0
# 3        4  02/02/20  6:00 PM                  Kerala       0       0
# 4        5  03/02/20  6:00 PM                  Kerala       0       0
# ...    ...       ...      ...                     ...     ...     ...
# 7081  7082  07/10/20  8:00 AM               Telangana  177008    1189
# 7082  7083  07/10/20  8:00 AM                 Tripura   22623     301
# 7083  7084  07/10/20  8:00 AM             Uttarakhand   43238     677
# 7084  7085  07/10/20  8:00 AM            UttarPradesh  370753    6153
# 7085  7086  07/10/20  8:00 AM              WestBengal  243743    5318
#
#       Confirmed
# 0             1
# 1             1
# 2             2
# 3             3
# 4             3
# ...         ...
# 7081     204748
# 7082      27545
# 7083      52329
# 7084     420937
# 7085     277049
#
# [7086 rows x 7 columns]

# %%
cured = data.groupby('StatesUniounTerritories').Cured.max()#seeing maximum cured by grouping satates 
cured
# Out:
# StatesUniounTerritories
# AndamanandNicobarIslands                3678
# AndhraPradesh                         672479
# ArunachalPradesh                        7965
# Assam                                 155077
# Bihar                                 178395
# Casesbeingreassignedtostates               0
# Chandigarh                             11035
# Chhattisgarh                          100551
# DadraandNagarHaveliandDamanandDiu       3000
# Delhi                                 266935
# Goa                                    31050
# Gujarat                               125111
# Haryana                               123286
# HimachalPradesh                        12918
# JammuandKashmir                        65496
# Jharkhand                              78089
# Karnataka                             533074
# Kerala                                154092
# Ladakh                                  3464
# MadhyaPradesh                         118039
# Maharashtra                          1179726
# Manipur                                 9482
# Meghalaya                               4606
# Mizoram                                 1887
# Nagaland                                5460
# Odisha                                210217
# Puducherry                             24614
# Punjab                                104355
# Rajasthan                             125448
# Sikkim                                  2587
# TamilNadu                             575212
# Telangana                             177008
# Tripura                                22623
# Unassigned                                 0
# UttarPradesh                          370753
# Uttarakhand                            43238
# WestBengal                            243743
# Name: Cured, dtype: int64

# %%
cured.plot(kind='bar', figsize=(14, 6),color='g')
plt.ylabel('No. of patients recovered (in lakhs)')
plt.xlabel('States & Union Territories')
plt.title('Covid19 recovered patients data in States & Union Territories of india')
plt.savefig('cured patients data in bar graph.png', bbox_inches = 'tight')
plt.grid()
plt.show()

# %%
max_deaths = data.groupby('StatesUniounTerritories').Deaths.max()#seeing maximum death by grouping satates
max_deaths
# Out:
# StatesUniounTerritories
# AndamanandNicobarIslands                54
# AndhraPradesh                         6052
# ArunachalPradesh                        20
# Assam                                  778
# Bihar                                  925
# Casesbeingreassignedtostates             0
# Chandigarh                             180
# Chhattisgarh                          1104
# DadraandNagarHaveliandDamanandDiu        2
# Delhi                                 5581
# Goa                                    468
# Gujarat                               3519
# Haryana                               1509
# HimachalPradesh                        229
# JammuandKashmir                       1268
# Jharkhand                              757
# Karnataka                             9461
# Kerala                                 884
# Ladakh                                  61
# MadhyaPradesh                         2488
# Maharashtra                          38717
# Manipur                                 78
# Meghalaya                               60
# Mizoram                                  0
# Nagaland                                17
# Odisha                                 940
# Puducherry                             546
# Punjab                                3679
# Rajasthan                             1574
# Sikkim                                  49
# TamilNadu                             9917
# Telangana                             1189
# Tripura                                301
# Unassigned                               0
# UttarPradesh                          6153
# Uttarakhand                            677
# WestBengal                            5318
# Name: Deaths, dtype: int64

# %%
max_deaths.plot(kind='bar', figsize=(14, 6),color='red')
plt.ylabel('Number of deaths')
plt.xlabel('States & Union Territories')
plt.title('Covid19 data on number of deaths in States & Union Territories of india')
plt.grid()
plt.savefig('death cases data bar graph2.png', bbox_inches = 'tight')

# %%
max_cases = data.groupby('StatesUniounTerritories').Confirmed.max()#seeing maximum cases in states by grouping satates
max_cases
# Out:
# StatesUniounTerritories
# AndamanandNicobarIslands                3912
# AndhraPradesh                         729307
# ArunachalPradesh                       11007
# Assam                                 188902
# Bihar                                 190740
# Casesbeingreassignedtostates            9265
# Chandigarh                             12707
# Chhattisgarh                          128893
# DadraandNagarHaveliandDamanandDiu       3103
# Delhi                                 295236
# Goa                                    36238
# Gujarat                               145200
# Haryana                               136115
# HimachalPradesh                        16283
# JammuandKashmir                        80476
# Jharkhand                              88873
# Karnataka                             657705
# Kerala                                242799
# Ladakh                                  4720
# MadhyaPradesh                         138668
# Maharashtra                          1465911
# Manipur                                12240
# Meghalaya                               7037
# Mizoram                                 2148
# Nagaland                                6662
# Odisha                                238003
# Puducherry                             29682
# Punjab                                120016
# Rajasthan                             148316
# Sikkim                                  3216
# TamilNadu                             630408
# Telangana                             204748
# Tripura                                27545
# Unassigned                                77
# UttarPradesh                          420937
# Uttarakhand                            52329
# WestBengal                            277049
# Name: Confirmed, dtype: int64

# %%
max_cases.sum()
# Out:
# 6766473

# %%
max_cases.plot(kind='bar', figsize=(14, 6))
plt.ylabel('Cases registered (in lakhs)')
plt.xlabel('States & Union Territories')
plt.grid()
plt.title('Covid19 cases registered in States & Union Territories of India')
plt.savefig("cases registered in states2.png", bbox_inches = 'tight')#to save this figure, filename.png, for fitin the size

# %%
#how many states affected
data['StatesUniounTerritories'].unique()
# Out:
# array(['Kerala', 'Telangana', 'Delhi', 'Rajasthan', 'UttarPradesh',
#        'Haryana', 'Ladakh', 'TamilNadu', 'Karnataka', 'Maharashtra',
#        'Punjab', 'JammuandKashmir', 'AndhraPradesh', 'Uttarakhand',
#        'Odisha', 'Puducherry', 'WestBengal', 'Chhattisgarh', 'Chandigarh',
#        'Gujarat', 'HimachalPradesh', 'MadhyaPradesh', 'Bihar', 'Manipur',
#        'Mizoram', 'AndamanandNicobarIslands', 'Goa', 'Unassigned',
#        'Assam', 'Jharkhand', 'ArunachalPradesh', 'Tripura', 'Nagaland',
#        'Meghalaya', 'DadraandNagarHaveliandDamanandDiu',
#        'Casesbeingreassignedtostates', 'Sikkim'], dtype=object)

# %%
len(data['StatesUniounTerritories'].unique())#how many states affected
# Out:
# 37

# %%
data.groupby(['Month']).sum()#determining step1 for groupby to choosing particuler column
# Out:
#            Sno      Cured   Deaths  Confirmed
# Month
# 1            3          0        0          2
# 2          493          0        0         86
# 3       139689        808      202       9687
# 4       952796      75443    13270     422442
# 5      2088522    1133341    89834    2938234
# 6      3311103    5668946   319690   10558374
# 7      4582965   19980130   793511   31726501
# 8      5695165   58580895  1553468   80749620
# 9      6632325  118592934  2443374  149113758
# 10     1706180   38556837   711884   45795597

# %%
results = data.groupby(['Month'])[["Confirmed", "Cured", "Deaths"]].max()#selecting particular columns to do groupby result
results
# Out:
#        Confirmed    Cured  Deaths
# Month
# 1              1        0       0
# 2              3        0       0
# 3            234       39       9
# 4           9915     1593     432
# 5          65168    28081    2197
# 6         169883    88960    7610
# 7         411798   248615   14729
# 8         780689   562401   24399
# 9        1366129  1069159   36181
# 10       1465911  1179726   38717

# %% [markdown]
# ### converting object date to date time format

# %%
data.dtypes#checking formats
# Out:
# Sno                         int64
# Date                       object
# Time                       object
# StatesUniounTerritories    object
# Cured                       int64
# Deaths                      int64
# Confirmed                   int64
# dtype: object

# %%
data['Time']= pd.to_datetime(data.Time)

# %%
data.tail(50)
# Out:
#        Sno      Date                Time            StatesUniounTerritories  \
# 7036  7037  06/10/20 2020-10-15 08:00:00                            Manipur
# 7037  7038  06/10/20 2020-10-15 08:00:00                          Meghalaya
# 7038  7039  06/10/20 2020-10-15 08:00:00                            Mizoram
# 7039  7040  06/10/20 2020-10-15 08:00:00                           Nagaland
# 7040  7041  06/10/20 2020-10-15 08:00:00                             Odisha
# 7041  7042  06/10/20 2020-10-15 08:00:00                         Puducherry
# 7042  7043  06/10/20 2020-10-15 08:00:00                             Punjab
# 7043  7044  06/10/20 2020-10-15 08:00:00                          Rajasthan
# 7044  7045  06/10/20 2020-10-15 08:00:00                             Sikkim
# 7045  7046  06/10/20 2020-10-15 08:00:00                          TamilNadu
# 7046  7047  06/10/20 2020-10-15 08:00:00                          Telangana
# 7047  7048  06/10/20 2020-10-15 08:00:00                            Tripura
# 7048  7049  06/10/20 2020-10-15 08:00:00                        Uttarakhand
# 7049  7050  06/10/20 2020-10-15 08:00:00                       UttarPradesh
# 7050  7051  06/10/20 2020-10-15 08:00:00                         WestBengal
# 7051  7052  07/10/20 2020-10-15 08:00:00           AndamanandNicobarIslands
# 7052  7053  07/10/20 2020-10-15 08:00:00                      AndhraPradesh
# 7053  7054  07/10/20 2020-10-15 08:00:00                   ArunachalPradesh
# 7054  7055  07/10/20 2020-10-15 08:00:00                              Assam
# 7055  7056  07/10/20 2020-10-15 08:00:00                              Bihar
# 7056  7057  07/10/20 2020-10-15 08:00:00                         Chandigarh
# 7057  7058  07/10/20 2020-10-15 08:00:00                       Chhattisgarh
# 7058  7059  07/10/20 2020-10-15 08:00:00  DadraandNagarHaveliandDamanandDiu
# 7059  7060  07/10/20 2020-10-15 08:00:00                              Delhi
# 7060  7061  07/10/20 2020-10-15 08:00:00                                Goa
# 7061  7062  07/10/20 2020-10-15 08:00:00                            Gujarat
# 7062  7063  07/10/20 2020-10-15 08:00:00                            Haryana
# 7063  7064  07/10/20 2020-10-15 08:00:00                    HimachalPradesh
# 7064  7065  07/10/20 2020-10-15 08:00:00                    JammuandKashmir
# 7065  7066  07/10/20 2020-10-15 08:00:00                          Jharkhand
# 7066  7067  07/10/20 2020-10-15 08:00:00                          Karnataka
# 7067  7068  07/10/20 2020-10-15 08:00:00                             Kerala
# 7068  7069  07/10/20 2020-10-15 08:00:00                             Ladakh
# 7069  7070  07/10/20 2020-10-15 08:00:00                      MadhyaPradesh
# 7070  7071  07/10/20 2020-10-15 08:00:00                        Maharashtra
# 7071  7072  07/10/20 2020-10-15 08:00:00                            Manipur
# 7072  7073  07/10/20 2020-10-15 08:00:00                          Meghalaya
# 7073  7074  07/10/20 2020-10-15 08:00:00                            Mizoram
# 7074  7075  07/10/20 2020-10-15 08:00:00                           Nagaland
# 7075  7076  07/10/20 2020-10-15 08:00:00                             Odisha
# 7076  7077  07/10/20 2020-10-15 08:00:00                         Puducherry
# 7077  7078  07/10/20 2020-10-15 08:00:00                             Punjab
# 7078  7079  07/10/20 2020-10-15 08:00:00                          Rajasthan
# 7079  7080  07/10/20 2020-10-15 08:00:00                             Sikkim
# 7080  7081  07/10/20 2020-10-15 08:00:00                          TamilNadu
# 7081  7082  07/10/20 2020-10-15 08:00:00                          Telangana
# 7082  7083  07/10/20 2020-10-15 08:00:00                            Tripura
# 7083  7084  07/10/20 2020-10-15 08:00:00                        Uttarakhand
# 7084  7085  07/10/20 2020-10-15 08:00:00                       UttarPradesh
# 7085  7086  07/10/20 2020-10-15 08:00:00                         WestBengal
#
#         Cured  Deaths  Confirmed
# 7036     9334      75      12105
# 7037     4491      59       6767
# 7038     1837       0       2128
# 7039     5422      17       6594
# 7040   206400     924     235330
# 7041    24221     543      29277
# 7042   102648    3641     119184
# 7043   123421    1559     146195
# 7044     2547      46       3191
# 7045   569664    9846     625391
# 7046   174769    1181     202594
# 7047    22131     301      27308
# 7048    42621     669      51991
# 7049   366321    6092     417437
# 7050   240707    5255     273679
# 7051     3678      54       3912
# 7052   672479    6052     729307
# 7053     7965      20      11007
# 7054   155077     778     188902
# 7055   178395     925     190740
# 7056    11035     180      12707
# 7057   100551    1104     128893
# 7058     3000       2       3103
# 7059   266935    5581     295236
# 7060    31050     468      36238
# 7061   125111    3519     145200
# 7062   123286    1509     136115
# 7063    12918     229      16283
# 7064    65496    1268      80476
# 7065    78089     757      88873
# 7066   533074    9461     657705
# 7067   154092     884     242799
# 7068     3464      61       4720
# 7069   118039    2488     138668
# 7070  1179726   38717    1465911
# 7071     9482      78      12240
# 7072     4606      60       7037
# 7073     1887       0       2148
# 7074     5460      17       6662
# 7075   210217     940     238003
# 7076    24614     546      29682
# 7077   104355    3679     120016
# 7078   125448    1574     148316
# 7079     2587      49       3216
# 7080   575212    9917     630408
# 7081   177008    1189     204748
# 7082    22623     301      27545
# 7083    43238     677      52329
# 7084   370753    6153     420937
# 7085   243743    5318     277049

# %%
del data['Time']#deleting column

# %%
data.head()
# Out:
#    Sno      Date StatesUniounTerritories  Cured  Deaths  Confirmed
# 0    1  30/01/20                  Kerala      0       0          1
# 1    2  31/01/20                  Kerala      0       0          1
# 2    3  01/02/20                  Kerala      0       0          2
# 3    4  02/02/20                  Kerala      0       0          3
# 4    5  03/02/20                  Kerala      0       0          3

# %%
data['Month'] = data['Date'].str[3:5]
data['Month'] = data['Month'].astype('int64')
data.head(5)
# Out:
#    Sno      Date StatesUniounTerritories  Cured  Deaths  Confirmed  Month
# 0    1  30/01/20                  Kerala      0       0          1      1
# 1    2  31/01/20                  Kerala      0       0          1      1
# 2    3  01/02/20                  Kerala      0       0          2      2
# 3    4  02/02/20                  Kerala      0       0          3      2
# 4    5  03/02/20                  Kerala      0       0          3      2

# %%
all_cured = cured.value_counts
all_cured
# Out:
# <bound method IndexOpsMixin.value_counts of StatesUniounTerritories
# AndamanandNicobarIslands                3678
# AndhraPradesh                         672479
# ArunachalPradesh                        7965
# Assam                                 155077
# Bihar                                 178395
# Casesbeingreassignedtostates               0
# Chandigarh                             11035
# Chhattisgarh                          100551
# DadraandNagarHaveliandDamanandDiu       3000
# Delhi                                 266935
# Goa                                    31050
# Gujarat                               125111
# Haryana                               123286
# HimachalPradesh                        12918
# JammuandKashmir                        65496
# Jharkhand                              78089
# Karnataka                             533074
# Kerala                                154092
# Ladakh                                  3464
# MadhyaPradesh                         118039
# Maharashtra                          1179726
# Manipur                                 9482
# Meghalaya                               4606
# Mizoram                                 1887
# Nagaland                                5460
# Odisha                                210217
# Puducherry                             24614
# Punjab                                104355
# Rajasthan                             125448
# Sikkim                                  2587
# TamilNadu                             575212
# Telangana                             177008
# Tripura                                22623
# Unassigned                                 0
# UttarPradesh                          370753
# Uttarakhand                            43238
# WestBengal                            243743
# Name: Cured, dtype: int64>

# %%
all_cases = max_cases.value_counts()
all_cases
# Out:
# 11007      1
# 238003     1
# 4720       1
# 80476      1
# 729307     1
# 630408     1
# 657705     1
# 190740     1
# 12240      1
# 27545      1
# 36238      1
# 77         1
# 204748     1
# 7037       1
# 420937     1
# 3912       1
# 16283      1
# 3103       1
# 12707      1
# 128893     1
# 2148       1
# 277049     1
# 1465911    1
# 3216       1
# 136115     1
# 29682      1
# 9265       1
# 145200     1
# 242799     1
# 52329      1
# 138668     1
# 120016     1
# 88873      1
# 6662       1
# 148316     1
# 188902     1
# 295236     1
# Name: Confirmed, dtype: int64

# %%
all_deaths = max_deaths.value_counts()
all_deaths
# Out:
# 0        3
# 5581     1
# 229      1
# 677      1
# 20       1
# 17       1
# 1104     1
# 78       1
# 38717    1
# 925      1
# 778      1
# 6153     1
# 5318     1
# 884      1
# 2        1
# 940      1
# 1189     1
# 3519     1
# 61       1
# 1268     1
# 60       1
# 9917     1
# 2488     1
# 54       1
# 757      1
# 180      1
# 49       1
# 546      1
# 468      1
# 301      1
# 9461     1
# 1574     1
# 1509     1
# 6052     1
# 3679     1
# Name: Deaths, dtype: int64

# %%
### Adding months column

# %%
data['Month'] = data['Date'].str[3:5]
data['Month'] = data['Month'].astype('int64')
data.head(5)
# Out:
#    Sno      Date StatesUniounTerritories  Cured  Deaths  Confirmed  Month
# 0    1  30/01/20                  Kerala      0       0          1      1
# 1    2  31/01/20                  Kerala      0       0          1      1
# 2    3  01/02/20                  Kerala      0       0          2      2
# 3    4  02/02/20                  Kerala      0       0          3      2
# 4    5  03/02/20                  Kerala      0       0          3      2

# %%
all_states = data.StatesUniounTerritories#seeing only particuler column
all_states
# Out:
# 0             Kerala
# 1             Kerala
# 2             Kerala
# 3             Kerala
# 4             Kerala
#             ...
# 7081       Telangana
# 7082         Tripura
# 7083     Uttarakhand
# 7084    UttarPradesh
# 7085      WestBengal
# Name: StatesUniounTerritories, Length: 7086, dtype: object

# %% [markdown]
# ## statewise data visualization till october 7 2020

# %% [markdown]
# # Telangana

# %%
telangana_data = data[data.StatesUniounTerritories.str.contains('Telangana')]#seeing only telengana values for finding incorrect spelling
telangana_data

# %%
month_telangana = telangana_data.groupby(['Month'])[['Confirmed', 'Cured', 'Deaths']].max()
month_telangana
# Out:
#        Confirmed   Cured  Deaths
# Month
# 3             79       1       1
# 4           1012     367      26
# 5           2499    1412      77
# 6          15394    5582     253
# 7          60717   44572     505
# 8         124963   92837     827
# 9         191386  160933    1127
# 10        204748  177008    1189

# %%
In [11]: month_telangana

# %%
month_telangana.plot(kind='bar', figsize=(16, 6))
plt.grid()
plt.ylabel('Covid19 cases(in lakhs)')
plt.xlabel('Months')
plt.title('Covid19 cases registered in different months in Telangana State')
plt.savefig("cases registered in telangana.png", bbox_inches = 'tight')#to save this figure, filename.png, for fitin the size

# %% [markdown]
# ### maximum cases reported in telangana

# %%
telangana_data.max()
# Out:
# Sno                             7082
# Date                        31/08/20
# StatesUniounTerritories    Telangana
# Cured                         177008
# Deaths                          1189
# Confirmed                     204748
# Month                             10
# dtype: object

# %% [markdown]
# # AndamanandNicobarIslands

# %%
AndamanandNicobarIslands_data = data[data.StatesUniounTerritories.str.contains('AndamanandNicobarIslands')]#seeing only telengana values for finding incorrect spelling
AndamanandNicobarIslands_data
# Out:
#        Sno      Date   StatesUniounTerritories  Cured  Deaths  Confirmed  \
# 365    366  26/03/20  AndamanandNicobarIslands      0       0          1
# 392    393  27/03/20  AndamanandNicobarIslands      0       0          1
# 420    421  28/03/20  AndamanandNicobarIslands      0       0          6
# 447    448  29/03/20  AndamanandNicobarIslands      0       0          9
# 474    475  30/03/20  AndamanandNicobarIslands      0       0          9
# ...    ...       ...                       ...    ...     ...        ...
# 6911  6912  03/10/20  AndamanandNicobarIslands   3631      53       3858
# 6946  6947  04/10/20  AndamanandNicobarIslands   3642      53       3868
# 6981  6982  05/10/20  AndamanandNicobarIslands   3649      53       3884
# 7016  7017  06/10/20  AndamanandNicobarIslands   3659      54       3899
# 7051  7052  07/10/20  AndamanandNicobarIslands   3678      54       3912
#
#       Month
# 365       3
# 392       3
# 420       3
# 447       3
# 474       3
# ...     ...
# 6911     10
# 6946     10
# 6981     10
# 7016     10
# 7051     10
#
# [196 rows x 7 columns]

# %%
month_AndamanandNicobarIslands = AndamanandNicobarIslands_data.groupby(['Month'])[['Confirmed', 'Cured', 'Deaths']].max()
month_AndamanandNicobarIslands
# Out:
#        Confirmed  Cured  Deaths
# Month
# 3             10      0       0
# 4             33     15       0
# 5             33     33       0
# 6             90     46       0
# 7            471    201       4
# 8           3104   2586      45
# 9           3821   3587      53
# 10          3912   3678      54

# %%
month_AndamanandNicobarIslands.plot(kind='bar', figsize=(16, 6))
plt.grid()
plt.ylabel('Covid19 cases')
plt.xlabel('Months')
plt.title('Covid19 cases registered in different months in Andaman and Nicobar Islands')
plt.savefig("cases registered in AndamanandNicobarIslands.png", bbox_inches = 'tight')#to save this figure, filename.png, for fitin the size

# %%
AndamanandNicobarIslands_data.max()
# Out:
# Sno                                            7052
# Date                                       31/08/20
# StatesUniounTerritories    AndamanandNicobarIslands
# Cured                                          3678
# Deaths                                           54
# Confirmed                                      3912
# Month                                            10
# dtype: object

# %% [markdown]
# # AndhraPradesh

# %%
AndhraPradesh_data = data[data.StatesUniounTerritories.str.contains('AndhraPradesh')]
AndhraPradesh_data
# Out:
#        Sno      Date StatesUniounTerritories   Cured  Deaths  Confirmed  Month
# 121    122  12/03/20           AndhraPradesh       0       0          1      3
# 134    135  13/03/20           AndhraPradesh       0       0          1      3
# 147    148  14/03/20           AndhraPradesh       0       0          1      3
# 148    149  15/03/20           AndhraPradesh       0       0          1      3
# 162    163  16/03/20           AndhraPradesh       0       0          1      3
# ...    ...       ...                     ...     ...     ...        ...    ...
# 6912  6913  03/10/20           AndhraPradesh  643993    5900     706790     10
# 6947  6948  04/10/20           AndhraPradesh  651791    5941     713014     10
# 6982  6983  05/10/20           AndhraPradesh  658875    5981     719256     10
# 7017  7018  06/10/20           AndhraPradesh  666433    6019     723512     10
# 7052  7053  07/10/20           AndhraPradesh  672479    6052     729307     10
#
# [210 rows x 7 columns]

# %%
month_AndhraPradesh = AndhraPradesh_data.groupby(['Month'])[['Confirmed', 'Cured', 'Deaths']].max()
month_AndhraPradesh
# Out:
#        Confirmed   Cured  Deaths
# Month
# 3             40       1       0
# 4           1403     321      31
# 5           3569    2289      60
# 6          13891    6232     180
# 7         130557   60024    1281
# 8         424767  321754    3884
# 9         687351  622136    5780
# 10        729307  672479    6052

# %%
month_AndhraPradesh.plot(kind='bar', figsize=(16, 6))
plt.grid()
plt.ylabel('Covid19 cases')
plt.xlabel('Months')
plt.title('Covid19 cases registered in different months in Andhra Pradesh')
plt.savefig("cases registered in AndhraPradesh.png", bbox_inches = 'tight')#to save this figure, filename.png, for fitin the size

# %%
AndhraPradesh_data.max()
# Out:
# Sno                                 7053
# Date                            31/08/20
# StatesUniounTerritories    AndhraPradesh
# Cured                             672479
# Deaths                              6052
# Confirmed                         729307
# Month                                 10
# dtype: object

# %% [markdown]
# # ArunachalPradesh

# %%
ArunachalPradesh_data = data[data.StatesUniounTerritories.str.contains('ArunachalPradesh')]
ArunachalPradesh_data
# Out:
#        Sno      Date StatesUniounTerritories  Cured  Deaths  Confirmed  Month
# 589    590  03/04/20        ArunachalPradesh      0       0          1      4
# 620    621  04/04/20        ArunachalPradesh      0       0          1      4
# 650    651  05/04/20        ArunachalPradesh      0       0          1      4
# 680    681  06/04/20        ArunachalPradesh      0       0          1      4
# 710    711  07/04/20        ArunachalPradesh      0       0          1      4
# ...    ...       ...                     ...    ...     ...        ...    ...
# 6913  6914  03/10/20        ArunachalPradesh   7183      18      10220     10
# 6948  6949  04/10/20        ArunachalPradesh   7388      18      10421     10
# 6983  6984  05/10/20        ArunachalPradesh   7577      18      10548     10
# 7018  7019  06/10/20        ArunachalPradesh   7775      19      10783     10
# 7053  7054  07/10/20        ArunachalPradesh   7965      20      11007     10
#
# [188 rows x 7 columns]

# %%
month_ArunachalPradesh = ArunachalPradesh_data.groupby(['Month'])[['Confirmed', 'Cured', 'Deaths']].max()
month_ArunachalPradesh
# Out:
#        Confirmed  Cured  Deaths
# Month
# 4              1      1       0
# 5              4      1       0
# 6            187     61       1
# 7           1484    827       3
# 8           4034   2822       7
# 9           9553   6743      16
# 10         11007   7965      20

# %%
month_ArunachalPradesh.plot(kind='bar', figsize=(16, 6))
plt.grid()
plt.ylabel('Covid19 cases')
plt.xlabel('Months')
plt.title('Covid19 cases registered in different months in Arunachal Pradesh')
plt.savefig("cases registered in ArunachalPradesh.png", bbox_inches = 'tight')#to save this figure, filename.png, for fitin the size

# %%
ArunachalPradesh_data.max()
# Out:
# Sno                                    7054
# Date                               31/08/20
# StatesUniounTerritories    ArunachalPradesh
# Cured                                  7965
# Deaths                                   20
# Confirmed                             11007
# Month                                    10
# dtype: object

# %% [markdown]
# # Assam

# %%
Assam_data = data[data.StatesUniounTerritories.str.contains('Assam')]
Assam_data
# Out:
#        Sno      Date StatesUniounTerritories   Cured  Deaths  Confirmed  Month
# 531    532  01/04/20                   Assam       0       0          1      4
# 560    561  02/04/20                   Assam       0       0          5      4
# 590    591  03/04/20                   Assam       0       0         16      4
# 621    622  04/04/20                   Assam       0       0         24      4
# 651    652  05/04/20                   Assam       0       0         26      4
# ...    ...       ...                     ...     ...     ...        ...    ...
# 6914  6915  03/10/20                   Assam  148963     721     183812     10
# 6949  6950  04/10/20                   Assam  150776     735     185444     10
# 6984  6985  05/10/20                   Assam  152127     749     186200     10
# 7019  7020  06/10/20                   Assam  153491     760     187718     10
# 7054  7055  07/10/20                   Assam  155077     778     188902     10
#
# [190 rows x 7 columns]

# %%
month_Assam = Assam_data.groupby(['Month'])[['Confirmed', 'Cured', 'Deaths']].max()
month_Assam
# Out:
#        Confirmed   Cured  Deaths
# Month
# 4             42      29       1
# 5           1185     163       4
# 6           7752    5333      11
# 7          38407   29080      94
# 8         105774   83927     296
# 9         177221  144002     680
# 10        188902  155077     778

# %%
month_Assam.plot(kind='bar', figsize=(16, 6))
plt.grid()
plt.ylabel('Covid19 cases')
plt.xlabel('Months')
plt.title('Covid19 cases registered in different months in Assam')
plt.savefig("cases registered in Assam.png", bbox_inches = 'tight')#to save this figure, filename.png, for fitin the size

# %%
Assam_data.max()
# Out:
# Sno                            7055
# Date                       31/08/20
# StatesUniounTerritories       Assam
# Cured                        155077
# Deaths                          778
# Confirmed                    188902
# Month                            10
# dtype: object

# %% [markdown]
# # Bihar

# %%
Bihar_data = data[data.StatesUniounTerritories.str.contains('Bihar')]
Bihar_data
# Out:
#        Sno      Date StatesUniounTerritories   Cured  Deaths  Confirmed  Month
# 271    272  22/03/20                   Bihar       0       1          2      3
# 294    295  23/03/20                   Bihar       0       1          2      3
# 317    318  24/03/20                   Bihar       0       1          3      3
# 341    342  25/03/20                   Bihar       0       1          4      3
# 367    368  26/03/20                   Bihar       0       1          6      3
# ...    ...       ...                     ...     ...     ...        ...    ...
# 6915  6916  03/10/20                   Bihar  172449     910     185436     10
# 6950  6951  04/10/20                   Bihar  173932     912     186441     10
# 6985  6986  05/10/20                   Bihar  175458     915     188168     10
# 7020  7021  06/10/20                   Bihar  176995     924     189442     10
# 7055  7056  07/10/20                   Bihar  178395     925     190740     10
#
# [200 rows x 7 columns]

# %%
month_Bihar = Bihar_data.groupby(['Month'])[['Confirmed', 'Cured', 'Deaths']].max()
month_Bihar
# Out:
#        Confirmed   Cured  Deaths
# Month
# 3             15       0       1
# 4            403      65       2
# 5           3636    1618      20
# 6           9640    7390      62
# 7          48477   31350     282
# 8         135035  117124     578
# 9         181285  168025     894
# 10        190740  178395     925

# %%
month_Bihar.plot(kind='bar', figsize=(16, 6))
plt.grid()
plt.ylabel('Covid19 cases')
plt.xlabel('Months')
plt.title('Covid19 cases registered in different months in Bihar')
plt.savefig("cases registered in Bihar.png", bbox_inches = 'tight')#to save this figure, filename.png, for fitin the size

# %% [markdown]
# # Chandigarh

# %%
Chandigarh_data = data[data.StatesUniounTerritories.str.contains('Chandigarh')]
Chandigarh_data
# Out:
#        Sno      Date StatesUniounTerritories  Cured  Deaths  Confirmed  Month
# 222    223  19/03/20              Chandigarh      0       0          1      3
# 242    243  20/03/20              Chandigarh      0       0          1      3
# 264    265  21/03/20              Chandigarh      0       0          1      3
# 287    288  22/03/20              Chandigarh      0       0          5      3
# 310    311  23/03/20              Chandigarh      0       0          6      3
# ...    ...       ...                     ...    ...     ...        ...    ...
# 6916  6917  03/10/20              Chandigarh  10162     169      12212     10
# 6951  6952  04/10/20              Chandigarh  10396     172      12360     10
# 6986  6987  05/10/20              Chandigarh  10598     174      12445     10
# 7021  7022  06/10/20              Chandigarh  10797     177      12578     10
# 7056  7057  07/10/20              Chandigarh  11035     180      12707     10
#
# [203 rows x 7 columns]

# %%
month_Chandigarh = Chandigarh_data.groupby(['Month'])[['Confirmed', 'Cured', 'Deaths']].max()
month_Chandigarh
# Out:
#        Confirmed  Cured  Deaths
# Month
# 3             13      0       0
# 4             56     17       0
# 5            289    189       4
# 6            435    349       6
# 7           1016    647      14
# 8           4155   2296      52
# 9          11816   9598     158
# 10         12707  11035     180

# %%
month_Chandigarh.plot(kind='bar', figsize=(16, 6))
plt.grid()
plt.ylabel('Covid19 cases')
plt.xlabel('Months')
plt.title('Covid19 cases registered in different months in Chandigarh')
plt.savefig("cases registered in Chandigarh.png", bbox_inches = 'tight')#to save this figure, filename.png, for fitin the size

# %% [markdown]
# # Chhattisgarh

# %%
Chhattisgarh_data = data[data.StatesUniounTerritories.str.contains('Chhattisgarh')]
Chandigarh_data
# Out:
#        Sno      Date StatesUniounTerritories  Cured  Deaths  Confirmed  Month
# 222    223  19/03/20              Chandigarh      0       0          1      3
# 242    243  20/03/20              Chandigarh      0       0          1      3
# 264    265  21/03/20              Chandigarh      0       0          1      3
# 287    288  22/03/20              Chandigarh      0       0          5      3
# 310    311  23/03/20              Chandigarh      0       0          6      3
# ...    ...       ...                     ...    ...     ...        ...    ...
# 6916  6917  03/10/20              Chandigarh  10162     169      12212     10
# 6951  6952  04/10/20              Chandigarh  10396     172      12360     10
# 6986  6987  05/10/20              Chandigarh  10598     174      12445     10
# 7021  7022  06/10/20              Chandigarh  10797     177      12578     10
# 7056  7057  07/10/20              Chandigarh  11035     180      12707     10
#
# [203 rows x 7 columns]

# %%
month_Chhattisgarh = Chhattisgarh_data.groupby(['Month'])[['Confirmed', 'Cured', 'Deaths']].max()
month_Chhattisgarh
# Out:
#        Confirmed   Cured  Deaths
# Month
# 3              8       0       0
# 4             38      36       0
# 5            447     102       1
# 6           2761    2173      13
# 7           8761    5921      51
# 8          30092   16303     269
# 9         110655   78514     916
# 10        128893  100551    1104

# %%
month_Chhattisgarh.plot(kind='bar', figsize=(16, 6))
plt.grid()
plt.ylabel('Covid19 cases')
plt.xlabel('Months')
plt.title('Covid19 cases registered in different months in Chhattisgarh')
plt.savefig("cases registered in Chhattisgarh.png", bbox_inches = 'tight')#to save this figure, filename.png, for fitin the size

# %% [markdown]
# # DadraandNagarHaveliandDamanandDiu

# %%
DadraandNagarHaveliandDamanandDiu_data = data[data.StatesUniounTerritories.str.contains('DadraandNagarHaveliandDamanandDiu')]
DadraandNagarHaveliandDamanandDiu_data
# Out:
#        Sno      Date            StatesUniounTerritories  Cured  Deaths  \
# 1645  1646  06/05/20  DadraandNagarHaveliandDamanandDiu      0       0
# 1678  1679  07/05/20  DadraandNagarHaveliandDamanandDiu      0       0
# 1711  1712  08/05/20  DadraandNagarHaveliandDamanandDiu      0       0
# 1744  1745  09/05/20  DadraandNagarHaveliandDamanandDiu      0       0
# 1777  1778  10/05/20  DadraandNagarHaveliandDamanandDiu      0       0
# ...    ...       ...                                ...    ...     ...
# 6918  6919  03/10/20  DadraandNagarHaveliandDamanandDiu   2959       2
# 6953  6954  04/10/20  DadraandNagarHaveliandDamanandDiu   2967       2
# 6988  6989  05/10/20  DadraandNagarHaveliandDamanandDiu   2980       2
# 7023  7024  06/10/20  DadraandNagarHaveliandDamanandDiu   2991       2
# 7058  7059  07/10/20  DadraandNagarHaveliandDamanandDiu   3000       2
#
#       Confirmed  Month
# 1645          1      5
# 1678          1      5
# 1711          1      5
# 1744          1      5
# 1777          1      5
# ...         ...    ...
# 6918       3061     10
# 6953       3070     10
# 6988       3087     10
# 7023       3092     10
# 7058       3103     10
#
# [156 rows x 7 columns]

# %%
month_DadraandNagarHaveliandDamanandDiu = DadraandNagarHaveliandDamanandDiu_data.groupby(['Month'])[['Confirmed', 'Cured', 'Deaths']].max()
month_DadraandNagarHaveliandDamanandDiu
# Out:
#        Confirmed  Cured  Deaths
# Month
# 5              2      0       0
# 6            203     77       0
# 7           1064    668       2
# 8           2340   2042       2
# 9           3032   2910       2
# 10          3103   3000       2

# %%
month_DadraandNagarHaveliandDamanandDiu.plot(kind='bar', figsize=(16, 6))
plt.grid()
plt.ylabel('Covid19 cases')
plt.xlabel('Months')
plt.title('Covid19 cases registered in different months in DadraandNagarHaveliandDamanandDiu')
plt.savefig("cases registered in DadraandNagarHaveliandDamanandDiu.png", bbox_inches = 'tight')#to save this figure, filename.png, for fitin the size

# %% [markdown]
# # Delhi

# %%
Delhi_data = data[data.StatesUniounTerritories.str.contains('Delhi')]
Delhi_data
# Out:
#        Sno      Date StatesUniounTerritories   Cured  Deaths  Confirmed  Month
# 34      35  02/03/20                   Delhi       0       0          1      3
# 38      39  03/03/20                   Delhi       0       0          1      3
# 42      43  04/03/20                   Delhi       0       0          1      3
# 45      46  05/03/20                   Delhi       0       0          2      3
# 51      52  06/03/20                   Delhi       0       0          3      3
# ...    ...       ...                     ...     ...     ...        ...    ...
# 6919  6920  03/10/20                   Delhi  253784    5438     285672     10
# 6954  6955  04/10/20                   Delhi  257224    5472     287930     10
# 6989  6990  05/10/20                   Delhi  260350    5510     290613     10
# 7024  7025  06/10/20                   Delhi  263938    5542     292560     10
# 7059  7060  07/10/20                   Delhi  266935    5581     295236     10
#
# [220 rows x 7 columns]

# %%
month_Delhi = Delhi_data.groupby(['Month'])[['Confirmed', 'Cured', 'Deaths']].max()
month_Delhi
# Out:
#        Confirmed   Cured  Deaths
# Month
# 3             97       6       2
# 4           3439    1092      56
# 5          18549    8075     416
# 6          85161   56235    2680
# 7         134403  119724    3936
# 8         173390  154171    4426
# 9         276325  243481    5320
# 10        295236  266935    5581

# %%
month_Delhi.plot(kind='bar', figsize=(16, 6))
plt.grid()
plt.ylabel('Covid19 cases')
plt.xlabel('Months')
plt.title('Covid19 cases registered in different months in Delhi')
plt.savefig("cases registered in Delhi.png", bbox_inches = 'tight')#to save this figure, filename.png, for fitin the size

# %% [markdown]
# # Gujarat

# %%
Gujarat_data = data[data.StatesUniounTerritories.str.contains('Gujarat')]
Gujarat_data
# Out:
#        Sno      Date StatesUniounTerritories   Cured  Deaths  Confirmed  Month
# 231    232  20/03/20                 Gujarat       0       0          5      3
# 251    252  21/03/20                 Gujarat       0       0          7      3
# 274    275  22/03/20                 Gujarat       0       1         18      3
# 297    298  23/03/20                 Gujarat       0       1         29      3
# 320    321  24/03/20                 Gujarat       0       1         33      3
# ...    ...       ...                     ...     ...     ...        ...    ...
# 6921  6922  03/10/20                 Gujarat  119683    3475     139893     10
# 6956  6957  04/10/20                 Gujarat  120987    3487     141236     10
# 6991  6992  05/10/20                 Gujarat  122233    3496     142538     10
# 7026  7027  06/10/20                 Gujarat  123638    3509     143865     10
# 7061  7062  07/10/20                 Gujarat  125111    3519     145200     10
#
# [202 rows x 7 columns]

# %%
month_Gujarat = Gujarat_data.groupby(['Month'])[['Confirmed', 'Cured', 'Deaths']].max()
month_Gujarat
# Out:
#        Confirmed   Cured  Deaths
# Month
# 3             73       3       6
# 4           4082     527     197
# 5          16343    9230    1007
# 6          31938   23240    1827
# 7          60285   44074    2418
# 8          95009   76731    3006
# 9         135842  115727    3439
# 10        145200  125111    3519

# %%
month_Gujarat.plot(kind='bar', figsize=(16, 6))
plt.grid()
plt.ylabel('Covid19 cases')
plt.xlabel('Months')
plt.title('Covid19 cases registered in different months in Gujarat')
plt.savefig("cases registered in Gujarat.png", bbox_inches = 'tight')#to save this figure, filename.png, for fitin the size

# %% [markdown]
# # Goa

# %%
Goa_data = data[data.StatesUniounTerritories.str.contains('Goa')]
Goa_data
# Out:
#        Sno      Date StatesUniounTerritories  Cured  Deaths  Confirmed  Month
# 371    372  26/03/20                     Goa      0       0          3      3
# 398    399  27/03/20                     Goa      0       0          3      3
# 425    426  28/03/20                     Goa      0       0          3      3
# 452    453  29/03/20                     Goa      0       0          5      3
# 479    480  30/03/20                     Goa      0       0          5      3
# ...    ...       ...                     ...    ...     ...        ...    ...
# 6920  6921  03/10/20                     Goa  29004     442      34455     10
# 6955  6956  04/10/20                     Goa  29527     450      34900     10
# 6990  6991  05/10/20                     Goa  30033     456      35328     10
# 7025  7026  06/10/20                     Goa  30456     460      35719     10
# 7060  7061  07/10/20                     Goa  31050     468      36238     10
#
# [196 rows x 7 columns]

# %%
month_Goa = Goa_data.groupby(['Month'])[['Confirmed', 'Cured', 'Deaths']].max()
month_Goa
# Out:
#        Confirmed  Cured  Deaths
# Month
# 3              5      0       0
# 4              7      7       0
# 5             70     41       0
# 6           1198    478       3
# 7           5704   4005      42
# 8          17004  13186     183
# 9          32777  27781     419
# 10         36238  31050     468

# %%
month_Goa.plot(kind='bar', figsize=(16, 6))
plt.grid()
plt.ylabel('Covid19 cases')
plt.xlabel('Months')
plt.title('Covid19 cases registered in different months in Goa')
plt.savefig("cases registered in Goa.png", bbox_inches = 'tight')#to save this figure, filename.png, for fitin the size

# %% [markdown]
# # Haryana

# %%
Haryana_data = data[data.StatesUniounTerritories.str.contains('Haryana')]
Haryana_data
# Out:
#        Sno      Date StatesUniounTerritories   Cured  Deaths  Confirmed  Month
# 41      42  04/03/20                 Haryana       0       0          2      3
# 46      47  05/03/20                 Haryana       0       0          2      3
# 52      53  06/03/20                 Haryana       0       0          2      3
# 63      64  07/03/20                 Haryana       0       0          2      3
# 70      71  08/03/20                 Haryana       0       0          2      3
# ...    ...       ...                     ...     ...     ...        ...    ...
# 6922  6923  03/10/20                 Haryana  116716    1425     131388     10
# 6957  6958  04/10/20                 Haryana  118258    1450     132576     10
# 6992  6993  05/10/20                 Haryana  120341    1470     133878     10
# 7027  7028  06/10/20                 Haryana  121596    1491     134909     10
# 7062  7063  07/10/20                 Haryana  123286    1509     136115     10
#
# [218 rows x 7 columns]

# %%
month_Haryana = Haryana_data.groupby(['Month'])[['Confirmed', 'Cured', 'Deaths']].max()
month_Haryana
# Out:
#        Confirmed   Cured  Deaths
# Month
# 3             40      21       0
# 4            310     209       3
# 5           1923     971      20
# 6          14210    9502     232
# 7          34254   27340     417
# 8          63282   51620     682
# 9         126974  110814    1356
# 10        136115  123286    1509

# %%
month_Haryana.plot(kind='bar', figsize=(16, 6))
plt.grid()
plt.ylabel('Covid19 cases')
plt.xlabel('Months')
plt.title('Covid19 cases registered in different months in Haryana')
plt.savefig("cases registered in Haryana.png", bbox_inches = 'tight')#to save this figure, filename.png, for fitin the size

# %% [markdown]
# # HimachalPradesh

# %%
HimachalPradesh_data = data[data.StatesUniounTerritories.str.contains('HimachalPradesh')]
HimachalPradesh_data
# Out:
#        Sno      Date StatesUniounTerritories  Cured  Deaths  Confirmed  Month
# 253    254  21/03/20         HimachalPradesh      0       0          2      3
# 276    277  22/03/20         HimachalPradesh      0       0          2      3
# 299    300  23/03/20         HimachalPradesh      0       0          2      3
# 322    323  24/03/20         HimachalPradesh      0       1          3      3
# 346    347  25/03/20         HimachalPradesh      0       1          3      3
# ...    ...       ...                     ...    ...     ...        ...    ...
# 6923  6924  03/10/20         HimachalPradesh  11996     202      15454     10
# 6958  6959  04/10/20         HimachalPradesh  12193     210      15695     10
# 6993  6994  05/10/20         HimachalPradesh  12361     217      15851     10
# 7028  7029  06/10/20         HimachalPradesh  12653     224      16033     10
# 7063  7064  07/10/20         HimachalPradesh  12918     229      16283     10
#
# [201 rows x 7 columns]

# %%
month_HimachalPradesh = HimachalPradesh_data.groupby(['Month'])[['Confirmed', 'Cured', 'Deaths']].max()
month_HimachalPradesh
# Out:
#        Confirmed  Cured  Deaths
# Month
# 3              3      0       1
# 4             40     25       1
# 5            313    111       5
# 6            942    556       9
# 7           2506   1387      14
# 8           5945   4450      35
# 9          14747  10991     183
# 10         16283  12918     229

# %%
month_HimachalPradesh.plot(kind='bar', figsize=(16, 6))
plt.grid()
plt.ylabel('Covid19 cases')
plt.xlabel('Months')
plt.title('Covid19 cases registered in different months in HimachalPradesh')
plt.savefig("cases registered in HimachalPradesh.png", bbox_inches = 'tight')#to save this figure, filename.png, for fitin the size

# %% [markdown]
# # JammuandKashmir

# %%
JammuandKashmir_data = data[data.StatesUniounTerritories.str.contains('JammuandKashmir')]
JammuandKashmir_data
# Out:
#        Sno      Date StatesUniounTerritories  Cured  Deaths  Confirmed  Month
# 81      82  09/03/20         JammuandKashmir      0       0          1      3
# 96      97  10/03/20         JammuandKashmir      0       0          1      3
# 106    107  11/03/20         JammuandKashmir      0       0          1      3
# 117    118  12/03/20         JammuandKashmir      0       0          1      3
# 130    131  13/03/20         JammuandKashmir      0       0          1      3
# ...    ...       ...                     ...    ...     ...        ...    ...
# 6924  6925  03/10/20         JammuandKashmir  59952    1212      77253     10
# 6959  6960  04/10/20         JammuandKashmir  61351    1231      78228     10
# 6994  6995  05/10/20         JammuandKashmir  62404    1242      79106     10
# 7029  7030  06/10/20         JammuandKashmir  63790    1252      79738     10
# 7064  7065  07/10/20         JammuandKashmir  65496    1268      80476     10
#
# [213 rows x 7 columns]

# %%
month_JammuandKashmir = JammuandKashmir_data.groupby(['Month'])[['Confirmed', 'Cured', 'Deaths']].max()
month_JammuandKashmir
# Out:
#        Confirmed  Cured  Deaths
# Month
# 3             54      2       2
# 4            581    192       8
# 5           2341    908      28
# 6           7237   4585      95
# 7          19869  11842     365
# 8          37163  28510     694
# 9          74095  55517    1164
# 10         80476  65496    1268

# %%
month_JammuandKashmir.plot(kind='bar', figsize=(16, 6))
plt.grid()
plt.ylabel('Covid19 cases')
plt.xlabel('Months')
plt.title('Covid19 cases registered in different months in JammuandKashmir')
plt.savefig("cases registered in JammuandKashmir.png", bbox_inches = 'tight')#to save this figure, filename.png, for fitin the size

# %% [markdown]
# # Jharkhand

# %%
Jharkhand_data = data[data.StatesUniounTerritories.str.contains('Jharkhand')]
Jharkhand_data
# Out:
#        Sno      Date StatesUniounTerritories  Cured  Deaths  Confirmed  Month
# 541    542  01/04/20               Jharkhand      0       0          1      4
# 570    571  02/04/20               Jharkhand      0       0          1      4
# 600    601  03/04/20               Jharkhand      0       0          2      4
# 631    632  04/04/20               Jharkhand      0       0          2      4
# 661    662  05/04/20               Jharkhand      0       0          3      4
# ...    ...       ...                     ...    ...     ...        ...    ...
# 6925  6926  03/10/20               Jharkhand  73428     729      85400     10
# 6960  6961  04/10/20               Jharkhand  74604     734      86277     10
# 6995  6996  05/10/20               Jharkhand  75531     743      87210     10
# 7030  7031  06/10/20               Jharkhand  76843     747      88026     10
# 7065  7066  07/10/20               Jharkhand  78089     757      88873     10
#
# [190 rows x 7 columns]

# %%
month_Jharkhand = Jharkhand_data.groupby(['Month'])[['Confirmed', 'Cured', 'Deaths']].max()
month_Jharkhand
# Out:
#        Confirmed  Cured  Deaths
# Month
# 4            107     19       3
# 5            563    256       5
# 6           2426   1845      15
# 7          10167   4176     103
# 8          38435  26448     410
# 9          82540  69898     700
# 10         88873  78089     757

# %%
month_Jharkhand.plot(kind='bar', figsize=(16, 6))
plt.grid()
plt.ylabel('Covid19 cases')
plt.xlabel('Months')
plt.title('Covid19 cases registered in different months in Jharkhand')
plt.savefig("cases registered in Jharkhand.png", bbox_inches = 'tight')#to save this figure, filename.png, for fitin the size

# %% [markdown]
# # Karnataka

# %%
Karnataka_data = data[data.StatesUniounTerritories.str.contains('Karnataka')]
Karnataka_data
# Out:
#        Sno      Date StatesUniounTerritories   Cured  Deaths  Confirmed  Month
# 74      75  09/03/20               Karnataka       0       0          1      3
# 89      90  10/03/20               Karnataka       0       0          4      3
# 108    109  11/03/20               Karnataka       0       0          4      3
# 119    120  12/03/20               Karnataka       0       0          4      3
# 132    133  13/03/20               Karnataka       0       1          6      3
# ...    ...       ...                     ...     ...     ...        ...    ...
# 6926  6927  03/10/20               Karnataka  499506    9119     620630     10
# 6961  6962  04/10/20               Karnataka  508495    9219     630516     10
# 6996  6997  05/10/20               Karnataka  515782    9286     640661     10
# 7031  7032  06/10/20               Karnataka  522846    9370     647712     10
# 7066  7067  07/10/20               Karnataka  533074    9461     657705     10
#
# [213 rows x 7 columns]

# %%
month_Karnataka = Karnataka_data.groupby(['Month'])[['Confirmed', 'Cured', 'Deaths']].max()
month_Karnataka
# Out:
#        Confirmed   Cured  Deaths
# Month
# 3             83       5       3
# 4            557     223      21
# 5           2922     997      48
# 6          14295    7683     226
# 7         118632   46694    2230
# 8         335928  242229    5589
# 9         592911  476378    8777
# 10        657705  533074    9461

# %%
month_Karnataka.plot(kind='bar', figsize=(16, 6))
plt.grid()
plt.ylabel('Covid19 cases')
plt.xlabel('Months')
plt.title('Covid19 cases registered in different months in Karnataka')
plt.savefig("cases registered in Karnataka.png", bbox_inches = 'tight')#to save this figure, filename.png, for fitin the size

# %% [markdown]
# # Kerala

# %%
Kerala_data = data[data.StatesUniounTerritories.str.contains('Kerala')]
Kerala_data
# Out:
#        Sno      Date StatesUniounTerritories   Cured  Deaths  Confirmed  Month
# 0        1  30/01/20                  Kerala       0       0          1      1
# 1        2  31/01/20                  Kerala       0       0          1      1
# 2        3  01/02/20                  Kerala       0       0          2      2
# 3        4  02/02/20                  Kerala       0       0          3      2
# 4        5  03/02/20                  Kerala       0       0          3      2
# ...    ...       ...                     ...     ...     ...        ...    ...
# 6927  6928  03/10/20                  Kerala  135144     791     213499     10
# 6962  6963  04/10/20                  Kerala  139620     813     221333     10
# 6997  6998  05/10/20                  Kerala  144471     836     229886     10
# 7032  7033  06/10/20                  Kerala  149111     859     234928     10
# 7067  7068  07/10/20                  Kerala  154092     884     242799     10
#
# [252 rows x 7 columns]

# %%
month_Kerala = Kerala_data.groupby(['Month'])[['Confirmed', 'Cured', 'Deaths']].max()
month_Kerala
# Out:
#        Confirmed   Cured  Deaths
# Month
# 1              1       0       0
# 2              3       0       0
# 3            234      19       1
# 4            496     369       4
# 5           1208     575       9
# 6           4189    2152      22
# 7          22303   12159      70
# 8          73855   49849     287
# 9         187276  124688     719
# 10        242799  154092     884

# %%
month_Kerala.plot(kind='bar', figsize=(16, 6))
plt.grid()
plt.ylabel('Covid19 cases')
plt.xlabel('Months')
plt.title('Covid19 cases registered in different months in Kerala')
plt.savefig("cases registered in Kerala.png", bbox_inches = 'tight')#to save this figure, filename.png, for fitin the size

# %% [markdown]
# # Ladakh

# %%
Ladakh_data = data[data.StatesUniounTerritories.str.contains('Ladakh')]
Ladakh_data
# Out:
#        Sno      Date StatesUniounTerritories  Cured  Deaths  Confirmed  Month
# 59      60  07/03/20                  Ladakh      0       0          2      3
# 65      66  08/03/20                  Ladakh      0       0          2      3
# 73      74  09/03/20                  Ladakh      0       0          2      3
# 86      87  10/03/20                  Ladakh      0       0          2      3
# 104    105  11/03/20                  Ladakh      0       0          2      3
# ...    ...       ...                     ...    ...     ...        ...    ...
# 6928  6929  03/10/20                  Ladakh   3274      61       4429     10
# 6963  6964  04/10/20                  Ladakh   3315      61       4477     10
# 6998  6999  05/10/20                  Ladakh   3354      61       4521     10
# 7033  7034  06/10/20                  Ladakh   3414      61       4641     10
# 7068  7069  07/10/20                  Ladakh   3464      61       4720     10
#
# [215 rows x 7 columns]

# %%
month_Ladakh = Goa_data.groupby(['Month'])[['Confirmed', 'Cured', 'Deaths']].max()
month_Ladakh
# Out:
#        Confirmed  Cured  Deaths
# Month
# 3              5      0       0
# 4              7      7       0
# 5             70     41       0
# 6           1198    478       3
# 7           5704   4005      42
# 8          17004  13186     183
# 9          32777  27781     419
# 10         36238  31050     468

# %%
month_Ladakh.plot(kind='bar', figsize=(16, 6))
plt.grid()
plt.ylabel('Covid19 cases')
plt.xlabel('Months')
plt.title('Covid19 cases registered in different months in Ladakh')
plt.savefig("cases registered in Ladakh.png", bbox_inches = 'tight')#to save this figure, filename.png, for fitin the size

# %% [markdown]
# # MadhyaPradesh

# %%
MadhyaPradesh_data = data[data.StatesUniounTerritories.str.contains('MadhyaPradesh')]
MadhyaPradesh_data
# Out:
#        Sno      Date StatesUniounTerritories   Cured  Deaths  Confirmed  Month
# 256    257  21/03/20           MadhyaPradesh       0       0          4      3
# 279    280  22/03/20           MadhyaPradesh       0       0          4      3
# 302    303  23/03/20           MadhyaPradesh       0       0          6      3
# 325    326  24/03/20           MadhyaPradesh       0       0          7      3
# 349    350  25/03/20           MadhyaPradesh       0       0         14      3
# ...    ...       ...                     ...     ...     ...        ...    ...
# 6929  6930  03/10/20           MadhyaPradesh  109611    2372     132107     10
# 6964  6965  04/10/20           MadhyaPradesh  111712    2399     133918     10
# 6999  7000  05/10/20           MadhyaPradesh  113832    2434     135638     10
# 7034  7035  06/10/20           MadhyaPradesh  115878    2463     137098     10
# 7069  7070  07/10/20           MadhyaPradesh  118039    2488     138668     10
#
# [201 rows x 7 columns]

# %%
month_MadhyaPradesh = MadhyaPradesh_data.groupby(['Month'])[['Confirmed', 'Cured', 'Deaths']].max()
month_MadhyaPradesh
# Out:
#        Confirmed   Cured  Deaths
# Month
# 3             47       0       3
# 4           2660     461     130
# 5           7891    4444     343
# 6          13370   10199     564
# 7          30968   21657     857
# 8          62433   47467    1374
# 9         126043  102445    2281
# 10        138668  118039    2488

# %%
month_MadhyaPradesh.plot(kind='bar', figsize=(16, 6))
plt.grid()
plt.ylabel('Covid19 cases')
plt.xlabel('Months')
plt.title('Covid19 cases registered in different months in MadhyaPradesh')
plt.savefig("cases registered in Goa.png", bbox_inches = 'tight')#to save this figure, filename.png, for fitin the size

# %% [markdown]
# # Maharashtra

# %%
Maharashtra_data = data[data.StatesUniounTerritories.str.contains('Maharashtra')]
Maharashtra_data
# Out:
#        Sno      Date StatesUniounTerritories    Cured  Deaths  Confirmed  \
# 76      77  09/03/20             Maharashtra        0       0          2
# 91      92  10/03/20             Maharashtra        0       0          5
# 97      98  11/03/20             Maharashtra        0       0          2
# 120    121  12/03/20             Maharashtra        0       0         11
# 133    134  13/03/20             Maharashtra        0       0         14
# ...    ...       ...                     ...      ...     ...        ...
# 6930  6931  03/10/20             Maharashtra  1117720   37480    1416513
# 6965  6966  04/10/20             Maharashtra  1134555   37758    1430861
# 7000  7001  05/10/20             Maharashtra  1149603   38084    1443409
# 7035  7036  06/10/20             Maharashtra  1162585   38347    1453653
# 7070  7071  07/10/20             Maharashtra  1179726   38717    1465911
#
#       Month
# 76        3
# 91        3
# 97        3
# 120       3
# 133       3
# ...     ...
# 6930     10
# 6965     10
# 7000     10
# 7035     10
# 7070     10
#
# [213 rows x 7 columns]

# %%
month_Maharashtra = Maharashtra_data.groupby(['Month'])[['Confirmed', 'Cured', 'Deaths']].max()
month_Maharashtra
# Out:
#        Confirmed    Cured  Deaths
# Month
# 3            216       39       9
# 4           9915     1593     432
# 5          65168    28081    2197
# 6         169883    88960    7610
# 7         411798   248615   14729
# 8         780689   562401   24399
# 9        1366129  1069159   36181
# 10       1465911  1179726   38717

# %%
month_Maharashtra.plot(kind='bar', figsize=(16, 6))
plt.grid()
plt.ylabel('Covid19 cases(in lakhs)')
plt.xlabel('Months')
plt.title('Covid19 cases registered in different months in Maharashtra')
plt.savefig("cases registered in Maharashtra.png", bbox_inches = 'tight')#to save this figure, filename.png, for fitin the size

# %% [markdown]
# # Manipur

# %%
Manipur_data = data[data.StatesUniounTerritories.str.contains('Manipur')]
Manipur_data
# Out:
#        Sno      Date StatesUniounTerritories  Cured  Deaths  Confirmed  Month
# 327    328  24/03/20                 Manipur      0       0          1      3
# 351    352  25/03/20                 Manipur      0       0          1      3
# 381    382  26/03/20                 Manipur      0       0          1      3
# 408    409  27/03/20                 Manipur      0       0          1      3
# 435    436  28/03/20                 Manipur      0       0          1      3
# ...    ...       ...                     ...    ...     ...        ...    ...
# 6931  6932  03/10/20                 Manipur   8992      69      11397     10
# 6966  6967  04/10/20                 Manipur   9081      71      11649     10
# 7001  7002  05/10/20                 Manipur   9205      74      11855     10
# 7036  7037  06/10/20                 Manipur   9334      75      12105     10
# 7071  7072  07/10/20                 Manipur   9482      78      12240     10
#
# [198 rows x 7 columns]

# %%
month_Manipur = Goa_data.groupby(['Month'])[['Confirmed', 'Cured', 'Deaths']].max()
month_Manipur
# Out:
#        Confirmed  Cured  Deaths
# Month
# 3              5      0       0
# 4              7      7       0
# 5             70     41       0
# 6           1198    478       3
# 7           5704   4005      42
# 8          17004  13186     183
# 9          32777  27781     419
# 10         36238  31050     468

# %%
month_Manipur.plot(kind='bar', figsize=(16, 6))
plt.grid()
plt.ylabel('Covid19 cases')
plt.xlabel('Months')
plt.title('Covid19 cases registered in different months in Manipur')
plt.savefig("cases registered in Manipur.png", bbox_inches = 'tight')#to save this figure, filename.png, for fitin the size

# %% [markdown]
# # Meghalaya

# %%
Meghalaya_data = data[data.StatesUniounTerritories.str.contains('Meghalaya')]
Meghalaya_data
# Out:
#        Sno      Date StatesUniounTerritories  Cured  Deaths  Confirmed  Month
# 946    947  14/04/20               Meghalaya      0       0          1      4
# 979    980  15/04/20               Meghalaya      0       1          7      4
# 1012  1013  16/04/20               Meghalaya      0       1          7      4
# 1045  1046  17/04/20               Meghalaya      0       1          9      4
# 1078  1079  18/04/20               Meghalaya      0       1         11      4
# ...    ...       ...                     ...    ...     ...        ...    ...
# 6932  6933  03/10/20               Meghalaya   4226      52       6033     10
# 6967  6968  04/10/20               Meghalaya   4319      54       6456     10
# 7002  7003  05/10/20               Meghalaya   4393      54       6656     10
# 7037  7038  06/10/20               Meghalaya   4491      59       6767     10
# 7072  7073  07/10/20               Meghalaya   4606      60       7037     10
#
# [177 rows x 7 columns]

# %%
month_Meghalaya = Manipur_data.groupby(['Month'])[['Confirmed', 'Cured', 'Deaths']].max()
month_Meghalaya
# Out:
#        Confirmed  Cured  Deaths
# Month
# 3              1      0       0
# 4              2      2       0
# 5             62      8       0
# 6           1227    494       0
# 7           2505   1672       4
# 8           6112   4239      28
# 9          10746   8039      65
# 10         12240   9482      78

# %%
month_Meghalaya.plot(kind='bar', figsize=(16, 6))
plt.grid()
plt.ylabel('Covid19 cases')
plt.xlabel('Months')
plt.title('Covid19 cases registered in different months in Meghalaya')
plt.savefig("cases registered in Meghalaya.png", bbox_inches = 'tight')#to save this figure, filename.png, for fitin the size

# %% [markdown]
# # Mizoram

# %%
Mizoram_data = data[data.StatesUniounTerritories.str.contains('Mizoram')]
Mizoram_data
# Out:
#        Sno      Date StatesUniounTerritories  Cured  Deaths  Confirmed  Month
# 352    353  25/03/20                 Mizoram      0       0          1      3
# 382    383  26/03/20                 Mizoram      0       0          1      3
# 409    410  27/03/20                 Mizoram      0       0          1      3
# 436    437  28/03/20                 Mizoram      0       0          1      3
# 463    464  29/03/20                 Mizoram      0       0          1      3
# ...    ...       ...                     ...    ...     ...        ...    ...
# 6933  6934  03/10/20                 Mizoram   1759       0       2103     10
# 6968  6969  04/10/20                 Mizoram   1772       0       2120     10
# 7003  7004  05/10/20                 Mizoram   1807       0       2120     10
# 7038  7039  06/10/20                 Mizoram   1837       0       2128     10
# 7073  7074  07/10/20                 Mizoram   1887       0       2148     10
#
# [197 rows x 7 columns]

# %%
month_Mizoram = Mizoram_data.groupby(['Month'])[['Confirmed', 'Cured', 'Deaths']].max()
month_Mizoram
# Out:
#        Confirmed  Cured  Deaths
# Month
# 3              1      0       0
# 4              1      0       0
# 5              1      1       0
# 6            148     55       0
# 7            408    234       0
# 8           1011    589       0
# 9           1986   1576       0
# 10          2148   1887       0

# %%
month_Mizoram.plot(kind='bar', figsize=(16, 6))
plt.grid()
plt.ylabel('Covid19 cases')
plt.xlabel('Months')
plt.title('Covid19 cases registered in different months in Mizoram')
plt.savefig("cases registered in Mizoram.png", bbox_inches = 'tight')#to save this figure, filename.png, for fitin the size

# %% [markdown]
# # Nagaland

# %%
Nagaland_data = data[data.StatesUniounTerritories.str.contains('Goa')]
Nagaland_data
# Out:
#        Sno      Date StatesUniounTerritories  Cured  Deaths  Confirmed  Month
# 371    372  26/03/20                     Goa      0       0          3      3
# 398    399  27/03/20                     Goa      0       0          3      3
# 425    426  28/03/20                     Goa      0       0          3      3
# 452    453  29/03/20                     Goa      0       0          5      3
# 479    480  30/03/20                     Goa      0       0          5      3
# ...    ...       ...                     ...    ...     ...        ...    ...
# 6920  6921  03/10/20                     Goa  29004     442      34455     10
# 6955  6956  04/10/20                     Goa  29527     450      34900     10
# 6990  6991  05/10/20                     Goa  30033     456      35328     10
# 7025  7026  06/10/20                     Goa  30456     460      35719     10
# 7060  7061  07/10/20                     Goa  31050     468      36238     10
#
# [196 rows x 7 columns]

# %%
month_Nagaland = Nagaland_data.groupby(['Month'])[['Confirmed', 'Cured', 'Deaths']].max()
month_Nagaland
# Out:
#        Confirmed  Cured  Deaths
# Month
# 3              5      0       0
# 4              7      7       0
# 5             70     41       0
# 6           1198    478       3
# 7           5704   4005      42
# 8          17004  13186     183
# 9          32777  27781     419
# 10         36238  31050     468

# %%
month_Nagaland.plot(kind='bar', figsize=(16, 6))
plt.grid()
plt.ylabel('Covid19 cases')
plt.xlabel('Months')
plt.title('Covid19 cases registered in different months in Nagaland')
plt.savefig("cases registered in Nagaland.png", bbox_inches = 'tight')#to save this figure, filename.png, for fitin the size

# %%
Goa_data = data[data.StatesUniounTerritories.str.contains('Goa')]
Goa_data
# Out:
#        Sno      Date StatesUniounTerritories  Cured  Deaths  Confirmed  Month
# 371    372  26/03/20                     Goa      0       0          3      3
# 398    399  27/03/20                     Goa      0       0          3      3
# 425    426  28/03/20                     Goa      0       0          3      3
# 452    453  29/03/20                     Goa      0       0          5      3
# 479    480  30/03/20                     Goa      0       0          5      3
# ...    ...       ...                     ...    ...     ...        ...    ...
# 6920  6921  03/10/20                     Goa  29004     442      34455     10
# 6955  6956  04/10/20                     Goa  29527     450      34900     10
# 6990  6991  05/10/20                     Goa  30033     456      35328     10
# 7025  7026  06/10/20                     Goa  30456     460      35719     10
# 7060  7061  07/10/20                     Goa  31050     468      36238     10
#
# [196 rows x 7 columns]

# %%
month_Goa = Goa_data.groupby(['Month'])[['Confirmed', 'Cured', 'Deaths']].max()
month_Goa
# Out:
#        Confirmed  Cured  Deaths
# Month
# 3              5      0       0
# 4              7      7       0
# 5             70     41       0
# 6           1198    478       3
# 7           5704   4005      42
# 8          17004  13186     183
# 9          32777  27781     419
# 10         36238  31050     468

# %%
month_Meghalaya.plot(kind='bar', figsize=(16, 6))
plt.grid()
plt.ylabel('Covid19 cases')
plt.xlabel('Months')
plt.title('Covid19 cases registered in different months in Meghalaya')
plt.savefig("cases registered in Meghalaya.png", bbox_inches = 'tight')#to save this figure, filename.png, for fitin the size

# %% [markdown]
# # Odisha

# %%
Odisha_data = data[data.StatesUniounTerritories.str.contains('Odisha')]
Odisha_data
# Out:
#        Sno      Date StatesUniounTerritories   Cured  Deaths  Confirmed  Month
# 168    169  16/03/20                  Odisha       0       0          1      3
# 183    184  17/03/20                  Odisha       0       0          1      3
# 198    199  18/03/20                  Odisha       0       0          1      3
# 216    217  19/03/20                  Odisha       0       0          1      3
# 236    237  20/03/20                  Odisha       0       0          2      3
# ...    ...       ...                     ...     ...     ...        ...    ...
# 6935  6936  03/10/20                  Odisha  194128     875     226334     10
# 6970  6971  04/10/20                  Odisha  198194     892     229387     10
# 7005  7006  05/10/20                  Odisha  202302     907     232713     10
# 7040  7041  06/10/20                  Odisha  206400     924     235330     10
# 7075  7076  07/10/20                  Odisha  210217     940     238003     10
#
# [206 rows x 7 columns]

# %%
month_Odisha = Odisha_data.groupby(['Month'])[['Confirmed', 'Cured', 'Deaths']].max()
month_Odisha
# Out:
#        Confirmed   Cured  Deaths
# Month
# 3              3       0       0
# 4            128      39       1
# 5           1819    1050       7
# 6           6859    4946      23
# 7          30378   19746     169
# 8         100934   73233     482
# 9         215676  181481     828
# 10        238003  210217     940

# %%
month_Odisha.plot(kind='bar', figsize=(16, 6))
plt.grid()
plt.ylabel('Covid19 cases')
plt.xlabel('Months')
plt.title('Covid19 cases registered in different months in Odisha')
plt.savefig("cases registered in Odisha.png", bbox_inches = 'tight')#to save this figure, filename.png, for fitin the size

# %% [markdown]
# # Puducherry

# %%
Puducherry_data = data[data.StatesUniounTerritories.str.contains('Puducherry')]
Puducherry_data
# Out:
#        Sno      Date StatesUniounTerritories  Cured  Deaths  Confirmed  Month
# 199    200  18/03/20              Puducherry      0       0          1      3
# 217    218  19/03/20              Puducherry      0       0          1      3
# 237    238  20/03/20              Puducherry      0       0          1      3
# 259    260  21/03/20              Puducherry      0       0          1      3
# 282    283  22/03/20              Puducherry      0       0          1      3
# ...    ...       ...                     ...    ...     ...        ...    ...
# 6936  6937  03/10/20              Puducherry  22948     532      28534     10
# 6971  6972  04/10/20              Puducherry  23344     534      28752     10
# 7006  7007  05/10/20              Puducherry  23763     539      29089     10
# 7041  7042  06/10/20              Puducherry  24221     543      29277     10
# 7076  7077  07/10/20              Puducherry  24614     546      29682     10
#
# [204 rows x 7 columns]

# %%
month_Puducherry = Puducherry_data.groupby(['Month'])[['Confirmed', 'Cured', 'Deaths']].max()
month_Puducherry
# Out:
#        Confirmed  Cured  Deaths
# Month
# 3              1      0       0
# 4              8      5       0
# 5             51     14       1
# 6            619    221      10
# 7           3298   1958      48
# 8          14127   8968     221
# 9          27066  21616     517
# 10         29682  24614     546

# %%
month_Puducherry.plot(kind='bar', figsize=(16, 6))
plt.grid()
plt.ylabel('Covid19 cases')
plt.xlabel('Months')
plt.title('Covid19 cases registered in different months in Puducherry')
plt.savefig("cases registered in Puducherry.png", bbox_inches = 'tight')#to save this figure, filename.png, for fitin the size

# %% [markdown]
# # Punjab

# %%
Punjab_data = data[data.StatesUniounTerritories.str.contains('Punjab')]
Punjab_data
# Out:
#        Sno      Date StatesUniounTerritories   Cured  Deaths  Confirmed  Month
# 77      78  09/03/20                  Punjab       0       0          1      3
# 92      93  10/03/20                  Punjab       0       0          1      3
# 107    108  11/03/20                  Punjab       0       0          1      3
# 118    119  12/03/20                  Punjab       0       0          1      3
# 131    132  13/03/20                  Punjab       0       0          1      3
# ...    ...       ...                     ...     ...     ...        ...    ...
# 6937  6938  03/10/20                  Punjab   97777    3501     116213     10
# 6972  6973  04/10/20                  Punjab   99468    3562     117319     10
# 7007  7008  05/10/20                  Punjab  100977    3603     118157     10
# 7042  7043  06/10/20                  Punjab  102648    3641     119184     10
# 7077  7078  07/10/20                  Punjab  104355    3679     120016     10
#
# [213 rows x 7 columns]

# %%
month_Punjab = Punjab_data.groupby(['Month'])[['Confirmed', 'Cured', 'Deaths']].max()
month_Punjab
# Out:
#        Confirmed   Cured  Deaths
# Month
# 3             41       1       3
# 4            357      90      19
# 5           2233    1967      44
# 6           5418    3764     138
# 7          15456   10509     370
# 8          52526   35747    1404
# 9         112460   92277    3359
# 10        120016  104355    3679

# %%
month_Punjab.plot(kind='bar', figsize=(16, 6))
plt.grid()
plt.ylabel('Covid19 cases')
plt.xlabel('Months')
plt.title('Covid19 cases registered in different months in Punjab')
plt.savefig("cases registered in Punjab.png", bbox_inches = 'tight')#to save this figure, filename.png, for fitin the size

# %% [markdown]
# # Rajasthan

# %%
Rajasthan_data = data[data.StatesUniounTerritories.str.contains('Rajasthan')]
Rajasthan_data
# Out:
#        Sno      Date StatesUniounTerritories   Cured  Deaths  Confirmed  Month
# 36      37  03/03/20               Rajasthan       0       0          1      3
# 44      45  04/03/20               Rajasthan       0       0         15      3
# 48      49  05/03/20               Rajasthan       0       0         15      3
# 54      55  06/03/20               Rajasthan       0       0         15      3
# 64      65  07/03/20               Rajasthan       0       0         15      3
# ...    ...       ...                     ...     ...     ...        ...    ...
# 6938  6939  03/10/20               Rajasthan  117238    1516     139696     10
# 6973  6974  04/10/20               Rajasthan  119241    1530     141846     10
# 7008  7009  05/10/20               Rajasthan  121331    1545     144030     10
# 7043  7044  06/10/20               Rajasthan  123421    1559     146195     10
# 7078  7079  07/10/20               Rajasthan  125448    1574     148316     10
#
# [219 rows x 7 columns]

# %%
month_Rajasthan = Rajasthan_data.groupby(['Month'])[['Confirmed', 'Cured', 'Deaths']].max()
month_Rajasthan
# Out:
#        Confirmed   Cured  Deaths
# Month
# 3             74       3       0
# 4           2438     768      51
# 5           8617    5739     193
# 6          17660   13618     405
# 7          40145   28385     663
# 8          80227   65093    1043
# 9         133119  111272    1471
# 10        148316  125448    1574

# %%
month_Rajasthan.plot(kind='bar', figsize=(16, 6))
plt.grid()
plt.ylabel('Covid19 cases')
plt.xlabel('Months')
plt.title('Covid19 cases registered in different months in Rajasthan')
plt.savefig("cases registered in Rajasthan.png", bbox_inches = 'tight')#to save this figure, filename.png, for fitin the size

# %% [markdown]
# # Sikkim

# %%
Sikkim_data = data[data.StatesUniounTerritories.str.contains('Sikkim')]
Sikkim_data
# Out:
#        Sno      Date StatesUniounTerritories  Cured  Deaths  Confirmed  Month
# 2263  2264  24/05/20                  Sikkim      0       0          1      5
# 2298  2299  25/05/20                  Sikkim      0       0          1      5
# 2334  2335  26/05/20                  Sikkim      0       0          1      5
# 2370  2371  27/05/20                  Sikkim      0       0          1      5
# 2406  2407  28/05/20                  Sikkim      0       0          1      5
# ...    ...       ...                     ...    ...     ...        ...    ...
# 6939  6940  03/10/20                  Sikkim   2409      41       3092     10
# 6974  6975  04/10/20                  Sikkim   2448      43       3131     10
# 7009  7010  05/10/20                  Sikkim   2480      45       3174     10
# 7044  7045  06/10/20                  Sikkim   2547      46       3191     10
# 7079  7080  07/10/20                  Sikkim   2587      49       3216     10
#
# [137 rows x 7 columns]

# %%
month_Sikkim = Sikkim_data.groupby(['Month'])[['Confirmed', 'Cured', 'Deaths']].max()
month_Sikkim
# Out:
#        Confirmed  Cured  Deaths
# Month
# 5              1      0       0
# 6             88     50       0
# 7            610    214       1
# 8           1627   1220       3
# 9           2937   2235      35
# 10          3216   2587      49

# %%
month_Sikkim.plot(kind='bar', figsize=(16, 6))
plt.grid()
plt.ylabel('Covid19 cases')
plt.xlabel('Months')
plt.title('Covid19 cases registered in different months in Sikkim')
plt.savefig("cases registered in Sikkim.png", bbox_inches = 'tight')#to save this figure, filename.png, for fitin the size

# %% [markdown]
# # TamilNadu

# %%
TamilNadu_data = data[data.StatesUniounTerritories.str.contains('TamilNadu')]
TamilNadu_data
# Out:
#        Sno      Date StatesUniounTerritories   Cured  Deaths  Confirmed  Month
# 61      62  07/03/20               TamilNadu       0       0          1      3
# 67      68  08/03/20               TamilNadu       0       0          1      3
# 79      80  09/03/20               TamilNadu       0       0          1      3
# 94      95  10/03/20               TamilNadu       0       0          1      3
# 105    106  11/03/20               TamilNadu       0       0          1      3
# ...    ...       ...                     ...     ...     ...        ...    ...
# 6940  6941  03/10/20               TamilNadu  552938    9653     608885     10
# 6975  6976  04/10/20               TamilNadu  558534    9718     614507     10
# 7010  7011  05/10/20               TamilNadu  564092    9784     619996     10
# 7045  7046  06/10/20               TamilNadu  569664    9846     625391     10
# 7080  7081  07/10/20               TamilNadu  575212    9917     630408     10
#
# [215 rows x 7 columns]

# %%
month_TamilNadu = TamilNadu_data.groupby(['Month'])[['Confirmed', 'Cured', 'Deaths']].max()
month_TamilNadu
# Out:
#        Confirmed   Cured  Deaths
# Month
# 3             74       4       1
# 4           2162    1210      27
# 5          21184   12000     160
# 6          86224   47749    1141
# 7         239978  178178    3838
# 8         422085  362133    7231
# 9         591943  536209    9453
# 10        630408  575212    9917

# %%
month_TamilNadu.plot(kind='bar', figsize=(16, 6))
plt.grid()
plt.ylabel('Covid19 cases')
plt.xlabel('Months')
plt.title('Covid19 cases registered in different months in TamilNadu')
plt.savefig("cases registered in TamilNadu.png", bbox_inches = 'tight')#to save this figure, filename.png, for fitin the size

# %% [markdown]
# # Tripura

# %%
Tripura_data = data[data.StatesUniounTerritories.str.contains('Tripura')]
Tripura_data
# Out:
#        Sno      Date StatesUniounTerritories  Cured  Deaths  Confirmed  Month
# 735    736  07/04/20                 Tripura      0       0          1      4
# 766    767  08/04/20                 Tripura      0       0          1      4
# 797    798  09/04/20                 Tripura      0       0          1      4
# 828    829  10/04/20                 Tripura      0       0          1      4
# 859    860  11/04/20                 Tripura      0       0          2      4
# ...    ...       ...                     ...    ...     ...        ...    ...
# 6942  6943  03/10/20                 Tripura  20897     289      26552     10
# 6977  6978  04/10/20                 Tripura  21410     293      26874     10
# 7012  7013  05/10/20                 Tripura  21876     299      27033     10
# 7047  7048  06/10/20                 Tripura  22131     301      27308     10
# 7082  7083  07/10/20                 Tripura  22623     301      27545     10
#
# [184 rows x 7 columns]

# %%
month_Tripura = Tripura_data.groupby(['Month'])[['Confirmed', 'Cured', 'Deaths']].max()
month_Tripura
# Out:
#        Confirmed  Cured  Deaths
# Month
# 4              2      2       0
# 5            268    172       0
# 6           1380   1085       1
# 7           4706   2962      21
# 8          11644   7433     103
# 9          25734  19692     277
# 10         27545  22623     301

# %%
month_Tripura.plot(kind='bar', figsize=(16, 6))
plt.grid()
plt.ylabel('Covid19 cases')
plt.xlabel('Months')
plt.title('Covid19 cases registered in different months in Tripura')
plt.savefig("cases registered in Tripura.png", bbox_inches = 'tight')#to save this figure, filename.png, for fitin the size

# %% [markdown]
# # UttarPradesh

# %%
UttarPradesh_data = data[data.StatesUniounTerritories.str.contains('UttarPradesh')]
UttarPradesh_data
# Out:
#        Sno      Date StatesUniounTerritories   Cured  Deaths  Confirmed  Month
# 39      40  04/03/20            UttarPradesh       0       0          6      3
# 50      51  05/03/20            UttarPradesh       0       0          7      3
# 55      56  06/03/20            UttarPradesh       0       0          7      3
# 58      59  07/03/20            UttarPradesh       0       0          7      3
# 72      73  08/03/20            UttarPradesh       0       0          7      3
# ...    ...       ...                     ...     ...     ...        ...    ...
# 6944  6945  03/10/20            UttarPradesh  351966    5917     406995     10
# 6979  6980  04/10/20            UttarPradesh  356826    5977     410626     10
# 7014  7015  05/10/20            UttarPradesh  362052    6029     414466     10
# 7049  7050  06/10/20            UttarPradesh  366321    6092     417437     10
# 7084  7085  07/10/20            UttarPradesh  370753    6153     420937     10
#
# [218 rows x 7 columns]

# %%
month_UttarPradesh = UttarPradesh_data.groupby(['Month'])[['Confirmed', 'Cured', 'Deaths']].max()
month_UttarPradesh
# Out:
#        Confirmed   Cured  Deaths
# Month
# 3            101      14       0
# 4           2203     513      39
# 5           7445    4410     201
# 6          22828   15506     672
# 7          81039   46803    1587
# 8         225632  167543    3423
# 9         394856  336981    5715
# 10        420937  370753    6153

# %%
month_UttarPradesh.plot(kind='bar', figsize=(16, 6))
plt.grid()
plt.ylabel('Covid19 cases')
plt.xlabel('Months')
plt.title('Covid19 cases registered in different months in UttarPradesh')
plt.savefig("cases registered in UttarPradesh.png", bbox_inches = 'tight')#to save this figure, filename.png, for fitin the size

# %% [markdown]
# # Uttarakhand

# %%
Uttarakhand_data = data[data.StatesUniounTerritories.str.contains('Uttarakhand')]
Uttarakhand_data
# Out:
#        Sno      Date StatesUniounTerritories  Cured  Deaths  Confirmed  Month
# 161    162  15/03/20             Uttarakhand      0       0          1      3
# 176    177  16/03/20             Uttarakhand      0       0          1      3
# 191    192  17/03/20             Uttarakhand      0       0          1      3
# 207    208  18/03/20             Uttarakhand      0       0          1      3
# 226    227  19/03/20             Uttarakhand      0       0          1      3
# ...    ...       ...                     ...    ...     ...        ...    ...
# 6943  6944  03/10/20             Uttarakhand  40419     636      49559     10
# 6978  6979  04/10/20             Uttarakhand  41338     648      50062     10
# 7013  7014  05/10/20             Uttarakhand  41740     652      51481     10
# 7048  7049  06/10/20             Uttarakhand  42621     669      51991     10
# 7083  7084  07/10/20             Uttarakhand  43238     677      52329     10
#
# [207 rows x 7 columns]

# %%
month_Uttarakhand = Uttarakhand_data.groupby(['Month'])[['Confirmed', 'Cured', 'Deaths']].max()
month_Uttarakhand
# Out:
#        Confirmed  Cured  Deaths
# Month
# 3              7      2       0
# 4             55     36       0
# 5            749    102       5
# 6           2831   2111      39
# 7           7065   3996      76
# 8          19235  13066     257
# 9          47995  38282     591
# 10         52329  43238     677

# %%
month_Uttarakhand.plot(kind='bar', figsize=(16, 6))
plt.grid()
plt.ylabel('Covid19 cases')
plt.xlabel('Months')
plt.title('Covid19 cases registered in different months in Uttarakhand')
plt.savefig("cases registered in Uttarakhand.png", bbox_inches = 'tight')#to save this figure, filename.png, for fitin the size

# %% [markdown]
# # WestBengal

# %%
WestBengal_data = data[data.StatesUniounTerritories.str.contains('WestBengal')]
WestBengal_data
# Out:
#        Sno      Date StatesUniounTerritories   Cured  Deaths  Confirmed  Month
# 208    209  18/03/20              WestBengal       0       0          1      3
# 227    228  19/03/20              WestBengal       0       0          1      3
# 247    248  20/03/20              WestBengal       0       0          2      3
# 269    270  21/03/20              WestBengal       0       0          3      3
# 292    293  22/03/20              WestBengal       0       0          4      3
# ...    ...       ...                     ...     ...     ...        ...    ...
# 6945  6946  03/10/20              WestBengal  231699    5070     263634     10
# 6980  6981  04/10/20              WestBengal  234712    5132     266974     10
# 7015  7016  05/10/20              WestBengal  237698    5194     270331     10
# 7050  7051  06/10/20              WestBengal  240707    5255     273679     10
# 7085  7086  07/10/20              WestBengal  243743    5318     277049     10
#
# [204 rows x 7 columns]

# %%
month_WestBengal = WestBengal_data.groupby(['Month'])[['Confirmed', 'Cured', 'Deaths']].max()
month_WestBengal
# Out:
#        Confirmed   Cured  Deaths
# Month
# 3             26       0       2
# 4            758     124      22
# 5           5130    1970     309
# 6          17907   11719     653
# 7          67692   46256    1536
# 8         159785  130952    3176
# 9         253768  222805    4899
# 10        277049  243743    5318

# %%
month_WestBengal.plot(kind='bar', figsize=(16, 6))
plt.grid()
plt.ylabel('Covid19 cases')
plt.xlabel('Months')
plt.title('Covid19 cases registered in different months in WestBengal')
plt.savefig("cases registered in WestBengal.png", bbox_inches = 'tight')#to save this figure, filename.png, for fitin the size

# %% [markdown]
# # maximum cases recorded in indian states

# %%
results = data.groupby(['Month'])[["Confirmed", "Cured", "Deaths"]].max()#selecting particular columns to do groupby result

# %%
results
# Out:
#                                       Sno     Cured   Deaths  Confirmed  Month
# StatesUniounTerritories
# AndamanandNicobarIslands           712793    166515     2701     206048   1278
# AndhraPradesh                      715952  25801839   292587   32689980   1320
# ArunachalPradesh                   709460    257632      666     375408   1252
# Assam                              710741   6719843    27255    8684022   1260
# Bihar                              714772   8427148    51043   10083708   1290
# Casesbeingreassignedtostates       191339         0        0     345565    366
# Chandigarh                         715766    308365     5741     441054   1299
# Chhattisgarh                       715859   2286326    29781    3664704   1299
# DadraandNagarHaveliandDamanandDiu  676985    149839      170     179373   1121
# Delhi                              717896  15548085   471261   18764283   1350
# Goa                                714485   1118457    16224    1466143   1278
# Gujarat                            716404   7250349   336932    9352521   1296
# Haryana                            718432   5087645    70933    6301253   1344
# HimachalPradesh                    716574    419710     5713     610636   1293
# JammuandKashmir                    718707   2546772    61840    3679663   1329
# Jharkhand                          712797   2527828    31237    3437401   1260
# Karnataka                          718977  19559143   442138   27374481   1329
# Kerala                             720025   4637086    26908    6970604   1413
# Ladakh                             719596    175151     2298     247921   1335
# MadhyaPradesh                      717759   4747828   149830    6285074   1293
# Maharashtra                        719784  51308834  2307966   74038022   1329
# Manipur                            717315    373269     2431     534606   1284
# Meghalaya                          704631    121049     1581     219923   1208
# Mizoram                            717361     57265        0      92306   1281
# Nagaland                           646481    219724      764     327031   1051
# Odisha                             719883   6935038    38887    8884624   1308
# Puducherry                         719734    802954    20113    1123543   1302
# Punjab                             721123   3502026   134241    4771572   1329
# Rajasthan                          721628   5902913   104936    7469420   1347
# Sikkim                             642287     92264      885     133692   1025
# TamilNadu                          721800  30224241   586759   36601887   1335
# Telangana                          722215   8134611    77681   10550954   1350
# Tripura                            712131    769028    10158    1124432   1236
# Unassigned                           1648         0        0        161     10
# UttarPradesh                       722758  14382732   304829   19085839   1344
# Uttarakhand                        721637   1382806    24656    1949296   1311
# WestBengal                         721506  10645019   284088   13247151   1302

# %%
data.isnull().sum()#finding null values
# Out:
# Sno                        0
# Date                       0
# StatesUniounTerritories    0
# Cured                      0
# Deaths                     0
# Confirmed                  0
# Month                      0
# dtype: int64

# %%
data.columns
# Out:
# Index(['Sno', 'Date', 'StatesUniounTerritories', 'Cured', 'Deaths',
#        'Confirmed', 'Month'],
#       dtype='object')
